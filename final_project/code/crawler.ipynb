# %% [markdown]
# # modules

# %%
import pandas as pd
import numpy as np
import requests
import json
import time
ts = time.time()
import pymongo
from bs4 import BeautifulSoup
import datetime

# %% [markdown]
# # naver 100

# %%
def naver_cat_id_maker(catID):
    url = "https://search.shopping.naver.com/best100v2/detail.nhn?catId=5000000" + str(catID)
    return url

# %%
def naver_top100():
    df = pd.DataFrame(columns=["from", "catID" ,"rank","item_name", "price", "link", "date"])
    for ID in range(0, 9):
        response = requests.get(naver_cat_id_maker(ID)) # html code로 가져옴
        dom = BeautifulSoup(response.content, "html.parser") # 파싱
        lists = dom.select(".type_normal li") #여러개의 데이터 (리스트)
        for rnk, lst in enumerate(lists):
            df.loc[len(df)] = {
                "from":"Naver",
                "catID":list(filter(lambda x: x!="", [cat if i == ID else "" for i, cat in enumerate (['패션의류', '패션잡화', '화장품/미용', '디지털/가전', '가구/인테리어', '출산/육아', '스포츠/레저', '식품', '생활/건강',])]))[0], 
                "rank":rnk + 1,
                "item_name":lst.select_one(".cont a").text,
                "price":lst.select_one(".price .num").text,
                "link":lst.select_one(".cont a").attrs['href'],
                "date":datetime.datetime.fromtimestamp(ts).strftime('%Y-%m-%d')
            }
    return df

# %%
# %%time
naver_df = naver_top100()
# Out:
# Wall time: 11.6 s

# %%
naver_df
# Out:
#       from  catID rank                     item_name      price  \
# 0    Naver   패션의류    1                     레드 체크 원피스     21,700
# 1    Naver   패션의류    2                   헤이즐 데일리 원피스     40,500
# 2    Naver   패션의류    3            스트라이프 브이넥 앞프릴 블라우스     17,670
# 3    Naver   패션의류    4                   플라워 자가드 반팔티     32,000
# 4    Naver   패션의류    5                     유하 프릴 원피스     46,000
# 5    Naver   패션의류    6                   은하수 스팽글 티셔츠     18,500
# 6    Naver   패션의류    7                 심리스 무봉제팬티 노라인      3,990
# 7    Naver   패션의류    8                미스티 플라워 쉬폰 원피스     37,800
# 8    Naver   패션의류    9                    꿀핏 부츠컷 제깅스     19,900
# 9    Naver   패션의류   10    Sensibility 오간자 카라 자수 블라우스     19,900
# 10   Naver   패션의류   11     충격흡수율 최고 쇼크업소버 스포츠브라탑 ...     36,400
# 11   Naver   패션의류   12           헤븐 오버핏 린넨 자켓 3color     59,900
# 12   Naver   패션의류   13         이프네 미로체크블라우스 DI4WBL31     18,950
# 13   Naver   패션의류   14                단독진행 젠틀 데일리 자켓     53,900
# 14   Naver   패션의류   15            루즈 모던재킷 C170704011     48,750
# 15   Naver   패션의류   16        ONLY VIVIA 하바나 투피스 set     33,900
# 16   Naver   패션의류   17     써스데이아일랜드 보더 포인트 프린트 원피...    158,440
# 17   Naver   패션의류   18   아디다스 콘디보16 트레이닝 팬츠 유소년 A...     29,370
# 18   Naver   패션의류   19                     샌드 타이 원피스     38,970
# 19   Naver   패션의류   20             상어가족 꼬리상하복 3color     17,500
# 20   Naver   패션의류   21           hone 9컬러데일리스트라이프티셔츠     10,050
# 21   Naver   패션의류   22    쉬즈미스 드라이프패텐원피스 SSSOPG51010     14,140
# 22   Naver   패션의류   23              리본 진주 브라보 반팔 티셔츠     19,800
# 23   Naver   패션의류   24                        봄 린넨자켓     42,000
# 24   Naver   패션의류   25     타미힐피거키즈 타미힐피거칠드런 져지 반팔...     19,600
# 25   Naver   패션의류   26                 데일리 레터링 반팔티셔츠     14,900
# 26   Naver   패션의류   27            아디다스 3S 레깅스 AJ8156     26,900
# 27   Naver   패션의류   28                 1 치타레터링 반팔티셔츠     14,900
# 28   Naver   패션의류   29     코데즈컴바인 절개브이티셔츠 CDBTS818W4     16,240
# 29   Naver   패션의류   30          멜로디가든 랄프 원피스 M8S3O22     48,550
# ..     ...    ...  ...                           ...        ...
# 870  Naver  생활/건강   71                 디자인에버 거짓말 탐지기      8,270
# 871  Naver  생활/건강   72            에스오일 세븐 골드 6L 5W30     15,660
# 872  Naver  생활/건강   73           창의메디칼 디스크닥터 WG50 G2    235,820
# 873  Naver  생활/건강   74    빈플러스 가정용 더치커피기구 마이더치 M3...     24,200
# 874  Naver  생활/건강   75               마도로스펫 치킨트릿 160g     20,000
# 875  Naver  생활/건강   76             네이월 눈물해방 소간육포 60g      2,900
# 876  Naver  생활/건강   77     대쉬크랩 터그 2in1 마그네틱 차량용 거치대     19,800
# 877  Naver  생활/건강   78       빈플러스 스텐 핸드드립 커피세트 102SD     27,900
# 878  Naver  생활/건강   79           베리어 고속 차량용 무선충전 거치대     24,800
# 879  Naver  생활/건강   80  복정제형 코지마 로얄킹덤 안마의자 CMC-79...  1,829,900
# 880  Naver  생활/건강   81               삼익 전자 디지털피아노 N2    360,480
# 881  Naver  생활/건강   82           리쏘 이지움2 안마의자 LS6700    980,000
# 882  Naver  생활/건강   83                     스테인레스 좌욕기      7,300
# 883  Naver  생활/건강   84                  3.3Kg 분말 소화기     17,900
# 884  Naver  생활/건강   85                카늘 체스 스마트폰 거치대     14,800
# 885  Naver  생활/건강   86             네이월 오리도가니 강아지 천염껌      3,200
# 886  Naver  생활/건강   87           마리헤즈 스프레이 밀대 걸레 청소기     19,160
# 887  Naver  생활/건강   88         웰킵스 스마트 황사마스크 KF94 소형        960
# 888  Naver  생활/건강   89                        컴팩트 컬링     18,900
# 889  Naver  생활/건강   90    디팡 펫플레이매트 소형견 폴딩 확장형 강아...     15,100
# 890  Naver  생활/건강   91              네이월 양등뼈 천연껌 200g      4,850
# 891  Naver  생활/건강   92    팜파스 미쁘 프리미엄 무형광 핸드타월 2겹...     14,310
# 892  Naver  생활/건강   93                페인트워크 클렌저 P21S     17,900
# 893  Naver  생활/건강   94    아리아 다본다 럭셔리 파워 차량용 진공 청...     41,790
# 894  Naver  생활/건강   95           3M 9010 식약청인증 황사마스크        670
# 895  Naver  생활/건강   96    아트뮤 퀵차지3.0 차량용 고속충전기 CC310      6,900
# 896  Naver  생활/건강   97                     이지119 소화기     14,320
# 897  Naver  생활/건강   98                      Y형 빨래건조대     10,670
# 898  Naver  생활/건강   99        클렙튼 KLEPTON 차량용  공기청정기     14,800
# 899  Naver  생활/건강  100         깨끗한나라 소프티 각티슈 250매*3개      3,020
#
#                                                   link        date
# 0    http://cr2.shopping.naver.com/adcr.nhn?x=NR%2F...  2018-04-21
# 1    http://cr2.shopping.naver.com/adcr.nhn?x=8xSgu...  2018-04-21
# 2    http://cr2.shopping.naver.com/adcr.nhn?x=ucEh9...  2018-04-21
# 3    http://cr2.shopping.naver.com/adcr.nhn?x=Xqqdi...  2018-04-21
# 4    http://cr2.shopping.naver.com/adcr.nhn?x=KYODE...  2018-04-21
# 5    http://cr2.shopping.naver.com/adcr.nhn?x=jBLC3...  2018-04-21
# 6    http://cr2.shopping.naver.com/adcr.nhn?x=rJ6er...  2018-04-21
# 7    http://cr2.shopping.naver.com/adcr.nhn?x=LqiIl...  2018-04-21
# 8    http://cr2.shopping.naver.com/adcr.nhn?x=CtANL...  2018-04-21
# 9    http://cr2.shopping.naver.com/adcr.nhn?x=mzrvw...  2018-04-21
# 10   http://cr2.shopping.naver.com/adcr.nhn?x=OtWWq...  2018-04-21
# 11   http://cr2.shopping.naver.com/adcr.nhn?x=LQj0s...  2018-04-21
# 12   http://cr2.shopping.naver.com/adcr.nhn?x=n66UK...  2018-04-21
# 13   http://cr2.shopping.naver.com/adcr.nhn?x=J1Jy3...  2018-04-21
# 14   http://cr2.shopping.naver.com/adcr.nhn?x=o5abz...  2018-04-21
# 15   http://cr2.shopping.naver.com/adcr.nhn?x=lHH9c...  2018-04-21
# 16   http://cr2.shopping.naver.com/adcr.nhn?x=ivOD5...  2018-04-21
# 17   http://cr2.shopping.naver.com/adcr.nhn?x=FiuSd...  2018-04-21
# 18   http://cr2.shopping.naver.com/adcr.nhn?x=68IF%...  2018-04-21
# 19   http://cr2.shopping.naver.com/adcr.nhn?x=oZGld...  2018-04-21
# 20   http://cr2.shopping.naver.com/adcr.nhn?x=CstMl...  2018-04-21
# 21   http://cr2.shopping.naver.com/adcr.nhn?x=T2ve5...  2018-04-21
# 22   http://cr2.shopping.naver.com/adcr.nhn?x=zF8aS...  2018-04-21
# 23   http://cr2.shopping.naver.com/adcr.nhn?x=tjBl%...  2018-04-21
# 24   http://cr2.shopping.naver.com/adcr.nhn?x=H8T2n...  2018-04-21
# 25   http://cr2.shopping.naver.com/adcr.nhn?x=6hBie...  2018-04-21
# 26   http://cr2.shopping.naver.com/adcr.nhn?x=%2BqW...  2018-04-21
# 27   http://cr2.shopping.naver.com/adcr.nhn?x=TQ1Xp...  2018-04-21
# 28   http://cr2.shopping.naver.com/adcr.nhn?x=8mDcA...  2018-04-21
# 29   http://cr2.shopping.naver.com/adcr.nhn?x=mkOgl...  2018-04-21
# ..                                                 ...         ...
# 870  http://cr2.shopping.naver.com/adcr.nhn?x=uLZ16...  2018-04-21
# 871  http://cr2.shopping.naver.com/adcr.nhn?x=x4KPF...  2018-04-21
# 872  http://cr2.shopping.naver.com/adcr.nhn?x=my2k4...  2018-04-21
# 873  http://cr2.shopping.naver.com/adcr.nhn?x=WhLKk...  2018-04-21
# 874  http://cr2.shopping.naver.com/adcr.nhn?x=5dSyv...  2018-04-21
# 875  http://cr2.shopping.naver.com/adcr.nhn?x=e6xG4...  2018-04-21
# 876  http://cr2.shopping.naver.com/adcr.nhn?x=9leoa...  2018-04-21
# 877  http://cr2.shopping.naver.com/adcr.nhn?x=QfcB3...  2018-04-21
# 878  http://cr2.shopping.naver.com/adcr.nhn?x=LyNSw...  2018-04-21
# 879  http://cr2.shopping.naver.com/adcr.nhn?x=Lcrsy...  2018-04-21
# 880  http://cr2.shopping.naver.com/adcr.nhn?x=yZnzh...  2018-04-21
# 881  http://cr2.shopping.naver.com/adcr.nhn?x=uIaVS...  2018-04-21
# 882  http://cr2.shopping.naver.com/adcr.nhn?x=2kWPX...  2018-04-21
# 883  http://cr2.shopping.naver.com/adcr.nhn?x=z7EUz...  2018-04-21
# 884  http://cr2.shopping.naver.com/adcr.nhn?x=7RSJh...  2018-04-21
# 885  http://cr2.shopping.naver.com/adcr.nhn?x=QwcTg...  2018-04-21
# 886  http://cr2.shopping.naver.com/adcr.nhn?x=AfR1G...  2018-04-21
# 887  http://cr2.shopping.naver.com/adcr.nhn?x=5dSuw...  2018-04-21
# 888  http://cr2.shopping.naver.com/adcr.nhn?x=n6HrN...  2018-04-21
# 889  http://cr2.shopping.naver.com/adcr.nhn?x=CQ2uO...  2018-04-21
# 890  http://cr2.shopping.naver.com/adcr.nhn?x=cAmRo...  2018-04-21
# 891  http://cr2.shopping.naver.com/adcr.nhn?x=5g%2B...  2018-04-21
# 892  http://cr2.shopping.naver.com/adcr.nhn?x=j1U9P...  2018-04-21
# 893  http://cr2.shopping.naver.com/adcr.nhn?x=R5wLe...  2018-04-21
# 894  http://cr2.shopping.naver.com/adcr.nhn?x=v8apy...  2018-04-21
# 895  http://cr2.shopping.naver.com/adcr.nhn?x=i5Ldm...  2018-04-21
# 896  http://cr2.shopping.naver.com/adcr.nhn?x=qq1g9...  2018-04-21
# 897  http://cr2.shopping.naver.com/adcr.nhn?x=ePvQ0...  2018-04-21
# 898  http://cr2.shopping.naver.com/adcr.nhn?x=PiHuw...  2018-04-21
# 899  http://cr2.shopping.naver.com/adcr.nhn?x=lL54T...  2018-04-21
#
# [900 rows x 7 columns]

# %% [markdown]
# # 도매꾹 100

# %%
def domaeggook_cat_id_maker(catID):
    url = "http://domeggook.com/main/item/itemPopular.php?cat=01_0" + str(catID)
    return url

# %%
def domaeggook_top100():
    df = pd.DataFrame(columns=["from", "catID" ,"rank","item_name", "price", "link", "date"])
    for ID in range(0, 6):
        response = requests.get(domaeggook_cat_id_maker(ID + 1)) # html code로 가져옴
        response.encoding = 'euc_kr'
        html = response.text
        dom = BeautifulSoup(html, "html.parser") # 파싱
        lists = dom.select("#itemPopularsUl li") #여러개의 데이터 (리스트)
        for rnk, lst in enumerate(lists):
            df.loc[len(df)] = {
                "from":"도매꾹",
                "catID":list(filter(lambda x: x!="", [cat if i == ID else "" for i, cat in enumerate (['패션잡화', '패션의류', '출산/육아', '가구/인테리어', '스포츠/레저', '디지털/가전',])]))[0], 
                "rank":rnk + 1,
                "item_name":lst.select_one(".info .title a").text.replace('\r','').replace('\n','').replace('\t',''),
                "price":lst.select_one(".info div:nth-of-type(2)").text[:len(lst.select_one(".info div:nth-of-type(2)").text)-1],
                "link":"http://domeggook.com/" + lst.select_one(".info .title a").attrs['href'],
                "date":datetime.datetime.fromtimestamp(ts).strftime('%Y-%m-%d')
            }
    return df

# %%
# %%time
domaeggook_df = domaeggook_top100()
# Out:
# Wall time: 7.2 s

# %%
domaeggook_df
# Out:
#     from   catID rank                                  item_name   price  \
# 0    도매꾹    패션잡화    1            북마크몰)KC인증 1006 심플 지갑모음/동전지갑/장지갑   2,900
# 1    도매꾹    패션잡화    2          [하이뷰]KC인증 a168/650원 헤어터번/헤어밴드/머리띠     650
# 2    도매꾹    패션잡화    3               쥬얼리 박스/귀걸이 보관함/악세서리 정리대/당일발송   5,900
# 3    도매꾹    패션잡화    4                [도매라인]신상입고*에코백/캔버스가방/화장품파우치   1,590
# 4    도매꾹    패션잡화    5             [하이뷰]KC인증/2900/여성지갑13종/반지갑/장지갑   2,900
# 5    도매꾹    패션잡화    6               모자/무지모자/볼캡/군모/야구모자/썬캡/정직한사람들   1,800
# 6    도매꾹    패션잡화    7              [다핀]180 신상 무지야구모자 볼캡 야유회 단체모자   1,800
# 7    도매꾹    패션잡화    8                준캡/롱스카프/무지스카프/스카프/머플러/쁘띠스카프     980
# 8    도매꾹    패션잡화    9                양말 페이크삭스 덧신 발목양말 실리콘/정직한사람들     550
# 9    도매꾹    패션잡화   10            2018년 신제품출시 신학기 백팩 책가방 학생가방 27종   8,300
# 10   도매꾹    패션잡화   11                푹신한 라텍스 쿠션깔창 깔창 기능성깔창 운동화깔창      \n
# 11   도매꾹    패션잡화   12           [하이뷰]초특가/701-650세안밴드23종/헤어밴드/헤어캡     650
# 12   도매꾹    패션잡화   13                슈퍼통/70종/트위스트머리끈/헤어밴드머리띠핀고무줄      55
# 13   도매꾹    패션잡화   14                 슈퍼통/스포츠선글라스/자외선차단안경고글등산자전거     980
# 14   도매꾹    패션잡화   15                에코백 캔버스 린넨 파우치 개별 포장 아름다운도매   1,690
# 15   도매꾹    패션잡화   16            북마크몰)KC인증 7001 트렌디 쁘띠/태슬/자석 스카프   1,200
# 16   도매꾹    패션잡화   17               슈퍼통/130종골드메달&형광칼라머리끈/헤어밴드머리띠      33
# 17   도매꾹    패션잡화   18                  투명비닐우산 자동우산 파스텔우산 성인 아동우산   1,200
# 18   도매꾹    패션잡화   19               [도매라인]최저가무지야구모자 볼캡/군모/스냅백/썬캡   1,320
# 19   도매꾹    패션잡화   20              [하이뷰]KC인증/2200/여성지갑8종/반지갑/장지갑   2,200
# 20   도매꾹    패션잡화   21              [도매라인]봄신상*양말 균일390원/페이크삭스골지양말     390
# 21   도매꾹    패션잡화   22               양말/발목양말 /페이크삭스/패션양말/아동양말/사은품     290
# 22   도매꾹    패션잡화   23                월드온 일러스트손거울 메이크업거울 화장거울 휴대용     110
# 23   도매꾹    패션잡화   24                       [주카페] 라이트 지퍼 에코백 10종   2,400
# 24   도매꾹    패션잡화   25               카네이션 브로치 모음전 도매꾹 최저가/어버이날/스승     900
# 25   도매꾹    패션잡화   26             북마크몰)KC인증8022 심플테슬 반지갑/태슬/여성지갑   4,500
# 26   도매꾹    패션잡화   27              실리콘 페이크삭스 남성 여성 덧신 양말 패션 선물 사     420
# 27   도매꾹    패션잡화   28               [착한가게]고품질 세안밴드/세안밴드 모음전/헤어악세     650
# 28   도매꾹    패션잡화   29              북마크몰)KC인증 800 여행 파우치/신발파우치/소풍   2,000
# 29   도매꾹    패션잡화   30             뷰티스토리 플로리스 제모기 4색상 왁싱/잔털제거/LED   6,900
# ..   ...     ...  ...                                        ...     ...
# 570  도매꾹  디지털/가전   71               [월드온] 초미니셀카봉 유선일체 아이폰 갤럭시 판촉     575
# 571  도매꾹  디지털/가전   72      속도UP 샌디스크 울트라 마이크로 SD UHS1 80MBs/64GB  20,700
# 572  도매꾹  디지털/가전   73             [더엘스타]스마트폰 자바라 거치대 집게형 / 한글포장    1,700
# 573  도매꾹  디지털/가전   74                아이크라운 방탄 강화유리 필름 갤럭시 아이폰 엘지     270
# 574  도매꾹  디지털/가전   75              [해브잇올] 트루글라스 곡면 풀커버 강화유리/추가금X   2,700
# 575  도매꾹  디지털/가전   76                  국내생산 고급택배박스/A형/E골/B골/포장박스  14,500
# 576  도매꾹  디지털/가전   77                [정품] 샤오미 보조배터리 10000mAh 2세대  15,200
# 577  도매꾹  디지털/가전   78               HEAD 전문가용 이발기 이발기구 전기 기계 바리깡  14,900
# 578  도매꾹  디지털/가전   79  크레이지 범퍼/G960/A530/노트8/G611/J530/G965/G950   1,300
# 579  도매꾹  디지털/가전   80                 i7 wh 무선 에어팟 이어팟 이어폰 하이퀄리티   7,900
# 580  도매꾹  디지털/가전   81          3D풀커버 강화유리필름/갤럭시S9/S9+/S8/노트8/아이폰   1,900
# 581  도매꾹  디지털/가전   82               [비앤제이]8핀젠더 데이타케이블 C-타입 젠더 입고     170
# 582  도매꾹  디지털/가전   83                스마트링.핸드폰링.인쇄가능.스마트폰.핑커링.품질좋     230
# 583  도매꾹  디지털/가전   84           스푼없이믹스커피타는기계 나비카페믹스 NV22-CAFEMIX      \n
# 584  도매꾹  디지털/가전   85      속도UP 샌디스크 울트라 마이크로 SD UHS1 80MBs/16GB   6,550
# 585  도매꾹  디지털/가전   86            ZIO 지오 ZENITH 45 in 1 멀티 카드 리더기   3,800
# 586  도매꾹  디지털/가전   87                   땡처리/kc인증 솜털제거기/면도기제모기사은품   6,500
# 587  도매꾹  디지털/가전   88                스마트링.핸드폰링.인쇄가능.스마트폰.핑커링.품질좋     240
# 588  도매꾹  디지털/가전   89            스키니 카본 매트케이스/초슬림/아이폰X 7 6/갤럭시s8     590
# 589  도매꾹  디지털/가전   90              [블루투스리모컨] 셀카봉리모컨/삼각대리모컨/KC/정품   1,850
# 590  도매꾹  디지털/가전   91                   c타입젠더 8핀젠더 지퍼팩 개별포장 가격동일     260
# 591  도매꾹  디지털/가전   92                                 카카오 빼꼼 케이스  15,500
# 592  도매꾹  디지털/가전   93             [월드온]고속충전케이블 5핀 8핀 c타입 숏/메탈케이블     590
# 593  도매꾹  디지털/가전   94             [폰핏]액티몬 5핀/8핀/C타입 가정용/차량용충전기젠더   1,400
# 594  도매꾹  디지털/가전   95                      아이폰 200% 정품 애플 2M 케이블   4,190
# 595  도매꾹  디지털/가전   96                       c타입젠더 8핀젠더 벌크포장 가격동일     170
# 596  도매꾹  디지털/가전   97              KC인증/생활방수/스마텍 STBT-N1블루투스 이어셋  14,100
# 597  도매꾹  디지털/가전   98                [ANB7]100종크롬라인TPU투명젤리케이스/S9   1,200
# 598  도매꾹  디지털/가전   99            [월드온] 360도풀커버케이스 아이폰X 갤럭시S9+ 노트   2,000
# 599  도매꾹  디지털/가전  100                월드온 차량용 보급형 송풍구 거치대 스마트폰 미니     550
#
#                               link        date
# 0    http://domeggook.com//6137839  2018-04-21
# 1    http://domeggook.com//7249848  2018-04-21
# 2    http://domeggook.com//7721016  2018-04-21
# 3    http://domeggook.com//3675454  2018-04-21
# 4    http://domeggook.com//7185397  2018-04-21
# 5    http://domeggook.com//5776935  2018-04-21
# 6    http://domeggook.com//6831391  2018-04-21
# 7    http://domeggook.com//7404453  2018-04-21
# 8    http://domeggook.com//5612074  2018-04-21
# 9    http://domeggook.com//6682744  2018-04-21
# 10   http://domeggook.com//6499015  2018-04-21
# 11   http://domeggook.com//7137941  2018-04-21
# 12   http://domeggook.com//6017351  2018-04-21
# 13   http://domeggook.com//5943062  2018-04-21
# 14   http://domeggook.com//6863285  2018-04-21
# 15   http://domeggook.com//6891832  2018-04-21
# 16   http://domeggook.com//5909011  2018-04-21
# 17   http://domeggook.com//6808595  2018-04-21
# 18   http://domeggook.com//4404744  2018-04-21
# 19   http://domeggook.com//7689058  2018-04-21
# 20   http://domeggook.com//3256419  2018-04-21
# 21   http://domeggook.com//5610024  2018-04-21
# 22   http://domeggook.com//7196348  2018-04-21
# 23   http://domeggook.com//7690787  2018-04-21
# 24   http://domeggook.com//7207401  2018-04-21
# 25   http://domeggook.com//6269312  2018-04-21
# 26   http://domeggook.com//7189222  2018-04-21
# 27   http://domeggook.com//7052778  2018-04-21
# 28   http://domeggook.com//7767013  2018-04-21
# 29   http://domeggook.com//7715660  2018-04-21
# ..                             ...         ...
# 570  http://domeggook.com//6094284  2018-04-21
# 571  http://domeggook.com//6607119  2018-04-21
# 572  http://domeggook.com//7781945  2018-04-21
# 573  http://domeggook.com//7298234  2018-04-21
# 574  http://domeggook.com//7475233  2018-04-21
# 575  http://domeggook.com//7373835  2018-04-21
# 576  http://domeggook.com//7692021  2018-04-21
# 577  http://domeggook.com//6766875  2018-04-21
# 578  http://domeggook.com//7261743  2018-04-21
# 579  http://domeggook.com//7767231  2018-04-21
# 580  http://domeggook.com//7418157  2018-04-21
# 581  http://domeggook.com//6644413  2018-04-21
# 582  http://domeggook.com//7203641  2018-04-21
# 583  http://domeggook.com//7469274  2018-04-21
# 584  http://domeggook.com//7172205  2018-04-21
# 585  http://domeggook.com//7650852  2018-04-21
# 586  http://domeggook.com//7748368  2018-04-21
# 587  http://domeggook.com//7202420  2018-04-21
# 588  http://domeggook.com//7405027  2018-04-21
# 589  http://domeggook.com//7415026  2018-04-21
# 590  http://domeggook.com//7250978  2018-04-21
# 591  http://domeggook.com//7467978  2018-04-21
# 592  http://domeggook.com//5873093  2018-04-21
# 593  http://domeggook.com//7600145  2018-04-21
# 594  http://domeggook.com//7137730  2018-04-21
# 595  http://domeggook.com//7760539  2018-04-21
# 596  http://domeggook.com//7561911  2018-04-21
# 597  http://domeggook.com//6898613  2018-04-21
# 598  http://domeggook.com//6700865  2018-04-21
# 599  http://domeggook.com//6823522  2018-04-21
#
# [600 rows x 7 columns]

# %% [markdown]
# # 도매매 100

# %%
def domaemae_cat_id_maker(catID1, catID2):
    url = "http://domeme.domeggook.com/main/item/supplyList.php?cat=0"+str(catID1)+"_0"+str(catID2)+"_00_00" 
    return url

# %%
response = requests.get(domaemae_cat_id_maker(1, 1)) # html code로 가져옴
response.encoding = 'euc-kr'
html = response.text
dom = BeautifulSoup(html, "html.parser") # 파싱
lists = dom.select(".lItemList li") #여러개의 데이터 (리스트)

# %%
lists
# Out:
# [<li class="col0 " id="li7249848">
#  <a class="thumb" href="/s/7249848" target="_blank">
#  <img alt="상품이미지" onerror="this.src = 'http://211.43.195.137/image/item/img_notExist330.gif'" src="http://211.43.195.137//upload/item/2017/05/31/14962275142E7C03C24D22B1424641BB/14962275142E7C03C24D22B1424641BB_stt_330.png" title="상품이미지"/>
#  </a>
#  <div class="main">
#  <div class="paidIcon">
#  </div>
#  <a class="title" href="/s/7249848" target="_blank">[하이뷰]KC인증 a168/650원 헤어터번/헤어밴드/머리띠</a>
#  </div>
#  <div class="amtqty">
#  <div class="markCompanyBlock">
#  								사업자회원만
#  								구매가능
#  							</div>
#  <div class="infoDeli">착불/선결제 <b>2,500</b>원</div> </div>
#  <ul class="subinfo">
#  <li>도매꾹판매</li> </ul>
#  <div class="seller">
#  <div class="nick">
#  <img alt="우수판매자" height="13" src="http://211.43.195.137/image/item/list/ico_goodSeller.png" title="우수판매자" width="17"/><img alt="파워멤버" height="13" src="http://211.43.195.137/image/item/list/ico_powerMember.png" title="파워멤버" width="13"/>
#  <a href="?sw=trendview&amp;sf=id">trendview</a>
#  </div>
#  <div class="grade">
#  <b>1</b>등급
#  					</div>
#  <div class="fastdeli">빠른배송</div>
#  </div>
#  <button class="otherButton" onclick="ToggleSellerItem('#li7249848', 'trendview', 'supply')" target="normal">
#  					판매자의 <b>다른상품</b>
#  </button>
#  <div class="others">
#  <ul></ul>
#  <a href="/main/item/itemList.php?sw=trendview&amp;sf=id" target="_blank">더보기 &gt;</a>
#  </div>
#  </li>, <li>도매꾹판매</li>, <li class="col1 " id="li5776935">
#  <a class="thumb" href="/s/5776935" target="_blank">
#  <img alt="상품이미지" onerror="this.src = 'http://211.43.195.137/image/item/img_notExist330.gif'" src="http://211.43.195.137//upload/item/2013/12/28/1388219887BB6ADFBDBDC4C1D5AE994C/1388219887BB6ADFBDBDC4C1D5AE994C_stt_330.png" title="상품이미지"/>
#  </a>
#  <div class="main">
#  <div class="paidIcon">
#  </div>
#  <a class="title" href="/s/5776935" target="_blank">모자/무지모자/볼캡/군모/야구모자/썬캡/정직한사람들</a>
#  </div>
#  <div class="amtqty">
#  <div class="markCompanyBlock">
#  								사업자회원만
#  								구매가능
#  							</div>
#  <div class="infoDeli">선결제 <b>2,500</b>원~</div> </div>
#  <ul class="subinfo">
#  <li>도매꾹판매</li> </ul>
#  <div class="seller">
#  <div class="nick">
#  <img alt="우수판매자" height="13" src="http://211.43.195.137/image/item/list/ico_goodSeller.png" title="우수판매자" width="17"/><img alt="파워멤버" height="13" src="http://211.43.195.137/image/item/list/ico_powerMember.png" title="파워멤버" width="13"/>
#  <a href="?sw=gtcity&amp;sf=id">정직한사람들</a>
#  </div>
#  <div class="id">(gtcity)</div> <div class="grade">
#  <b>1</b>등급
#  					</div>
#  <div class="fastdeli">빠른배송</div>
#  </div>
#  <button class="otherButton" onclick="ToggleSellerItem('#li5776935', 'gtcity', 'supply')" target="normal">
#  					판매자의 <b>다른상품</b>
#  </button>
#  <div class="others">
#  <ul></ul>
#  <a href="/main/item/itemList.php?sw=gtcity&amp;sf=id" target="_blank">더보기 &gt;</a>
#  </div>
#  </li>, <li>도매꾹판매</li>, <li class="col2 " id="li6831391">
#  <a class="thumb" href="/s/6831391" target="_blank">
#  <img alt="상품이미지" onerror="this.src = 'http://211.43.195.137/image/item/img_notExist330.gif'" src="http://211.43.195.137//upload/item/2016/06/17/146614298225B33523E2DA5E4D594B5D/146614298225B33523E2DA5E4D594B5D_stt_330.png" title="상품이미지"/>
#  </a>
#  <div class="main">
#  <div class="paidIcon">
#  </div>
#  <a class="title" href="/s/6831391" target="_blank">[다핀]180 신상 무지야구모자 볼캡 야유회 단체모자</a>
#  </div>
#  <div class="amtqty">
#  <div class="markCompanyBlock">
#  								사업자회원만
#  								구매가능
#  							</div>
#  <div class="infoDeli">착불/선결제 <b>2,500</b>원~</div> </div>
#  <ul class="subinfo">
#  <li>도매꾹판매</li> </ul>
#  <div class="seller">
#  <div class="nick">
#  <img alt="우수판매자" height="13" src="http://211.43.195.137/image/item/list/ico_goodSeller.png" title="우수판매자" width="17"/>
#  <a href="?sw=daacc56&amp;sf=id">다핀</a>
#  </div>
#  <div class="id">(daacc56)</div> <div class="grade">
#  <b>1</b>등급
#  					</div>
#  <div class="fastdeli">빠른배송</div>
#  </div>
#  <button class="otherButton" onclick="ToggleSellerItem('#li6831391', 'daacc56', 'supply')" target="normal">
#  					판매자의 <b>다른상품</b>
#  </button>
#  <div class="others">
#  <ul></ul>
#  <a href="/main/item/itemList.php?sw=daacc56&amp;sf=id" target="_blank">더보기 &gt;</a>
#  </div>
#  </li>, <li>도매꾹판매</li>, <li class="col3 " id="li6891832">
#  <a class="thumb" href="/s/6891832" target="_blank">
#  <img alt="상품이미지" onerror="this.src = 'http://211.43.195.137/image/item/img_notExist330.gif'" src="http://211.43.195.137//upload/item/2016/07/27/1469613340A48E2741D4BCBBEA8BD975/1469613340A48E2741D4BCBBEA8BD975_stt_330.png" title="상품이미지"/>
#  </a>
#  <div class="main">
#  <div class="paidIcon">
#  </div>
#  <a class="title" href="/s/6891832" target="_blank">북마크몰)KC인증 7001 트렌디 쁘띠/태슬/자석 스카프</a>
#  </div>
#  <div class="amtqty">
#  <div class="markCompanyBlock">
#  								사업자회원만
#  								구매가능
#  							</div>
#  <div class="infoDeli">착불/선결제 <b>2,500</b>원</div> </div>
#  <ul class="subinfo">
#  <li>도매꾹판매</li> </ul>
#  <div class="seller">
#  <div class="nick">
#  <img alt="파워멤버" height="13" src="http://211.43.195.137/image/item/list/ico_powerMember.png" title="파워멤버" width="13"/>
#  <a href="?sw=murina3&amp;sf=id">북마크</a>
#  </div>
#  <div class="id">(murina3)</div> <div class="grade">
#  <b>1</b>등급
#  					</div>
#  <div class="fastdeli">빠른배송</div>
#  </div>
#  <button class="otherButton" onclick="ToggleSellerItem('#li6891832', 'murina3', 'supply')" target="normal">
#  					판매자의 <b>다른상품</b>
#  </button>
#  <div class="others">
#  <ul></ul>
#  <a href="/main/item/itemList.php?sw=murina3&amp;sf=id" target="_blank">더보기 &gt;</a>
#  </div>
#  </li>, <li>도매꾹판매</li>, <li class="col0 " id="li6017351">
#  <a class="thumb" href="/s/6017351" target="_blank">
#  <img alt="상품이미지" onerror="this.src = 'http://211.43.195.137/image/item/img_notExist330.gif'" src="http://211.43.195.137//upload/item/2014/09/14/14106784233BB3AC271B7346A51B89B9/14106784233BB3AC271B7346A51B89B9_stt_330.png" title="상품이미지"/>
#  </a>
#  <div class="main">
#  <div class="paidIcon">
#  </div>
#  <a class="title" href="/s/6017351" target="_blank">슈퍼통/70종/트위스트머리끈/헤어밴드머리띠핀고무줄</a>
#  </div>
#  <div class="amtqty">
#  <div class="markCompanyBlock">
#  								사업자회원만
#  								구매가능
#  							</div>
#  <div class="infoDeli">착불/선결제 <b>2,500</b>원</div> </div>
#  <ul class="subinfo">
#  <li>도매꾹판매</li> </ul>
#  <div class="seller">
#  <div class="nick">
#  <img alt="우수판매자" height="13" src="http://211.43.195.137/image/item/list/ico_goodSeller.png" title="우수판매자" width="17"/>
#  <a href="?sw=juicykat&amp;sf=id">슈퍼통</a>
#  </div>
#  <div class="id">(juicykat)</div> <div class="grade">
#  <b>1</b>등급
#  					</div>
#  <div class="fastdeli">빠른배송</div>
#  </div>
#  </li>, <li>도매꾹판매</li>, <li class="col1 " id="li5943062">
#  <a class="thumb" href="/s/5943062" target="_blank">
#  <img alt="상품이미지" onerror="this.src = 'http://211.43.195.137/image/item/img_notExist330.gif'" src="http://211.43.195.137//upload/item/2014/06/27/14038519199E6C067508FD4B268ECE90/14038519199E6C067508FD4B268ECE90_stt_330.png" title="상품이미지"/>
#  </a>
#  <div class="main">
#  <div class="paidIcon">
#  </div>
#  <a class="title" href="/s/5943062" target="_blank">슈퍼통/스포츠선글라스/자외선차단안경고글등산자전거</a>
#  </div>
#  <div class="amtqty">
#  <div class="markCompanyBlock">
#  								사업자회원만
#  								구매가능
#  							</div>
#  <div class="infoDeli">착불/선결제 <b>2,500</b>원</div> </div>
#  <ul class="subinfo">
#  <li>도매꾹판매</li> </ul>
#  <div class="seller">
#  <div class="nick">
#  <img alt="우수판매자" height="13" src="http://211.43.195.137/image/item/list/ico_goodSeller.png" title="우수판매자" width="17"/>
#  <a href="?sw=juicykat&amp;sf=id">슈퍼통</a>
#  </div>
#  <div class="id">(juicykat)</div> <div class="grade">
#  <b>1</b>등급
#  					</div>
#  <div class="fastdeli">빠른배송</div>
#  </div>
#  </li>, <li>도매꾹판매</li>, <li class="col2 " id="li5909011">
#  <a class="thumb" href="/s/5909011" target="_blank">
#  <img alt="상품이미지" onerror="this.src = 'http://211.43.195.137/image/item/img_notExist330.gif'" src="http://211.43.195.137//upload/item/2014/05/22/1400689330E7EC3A1E98C37DE5B58A59/1400689330E7EC3A1E98C37DE5B58A59_stt_330.png" title="상품이미지"/>
#  </a>
#  <div class="main">
#  <div class="paidIcon">
#  </div>
#  <a class="title" href="/s/5909011" target="_blank">슈퍼통/130종골드메달&amp;형광칼라머리끈/헤어밴드머리띠</a>
#  </div>
#  <div class="amtqty">
#  <div class="markCompanyBlock">
#  								사업자회원만
#  								구매가능
#  							</div>
#  <div class="infoDeli">착불/선결제 <b>2,500</b>원</div> </div>
#  <ul class="subinfo">
#  <li>도매꾹판매</li> </ul>
#  <div class="seller">
#  <div class="nick">
#  <img alt="우수판매자" height="13" src="http://211.43.195.137/image/item/list/ico_goodSeller.png" title="우수판매자" width="17"/>
#  <a href="?sw=juicykat&amp;sf=id">슈퍼통</a>
#  </div>
#  <div class="id">(juicykat)</div> <div class="grade">
#  <b>1</b>등급
#  					</div>
#  <div class="fastdeli">빠른배송</div>
#  </div>
#  </li>, <li>도매꾹판매</li>, <li class="col3 " id="li5972106">
#  <a class="thumb" href="/s/5972106" target="_blank">
#  <img alt="상품이미지" onerror="this.src = 'http://211.43.195.137/image/item/img_notExist330.gif'" src="http://211.43.195.137//upload/item/2014/07/24/14061371654B6F91BC8FFD9B447FD85A/14061371654B6F91BC8FFD9B447FD85A_stt_330.png" title="상품이미지"/>
#  </a>
#  <div class="main">
#  <div class="paidIcon">
#  </div>
#  <a class="title" href="/s/5972106" target="_blank">슈퍼통/하트선글라스10종/자외선차단안경썬캡여름여행</a>
#  </div>
#  <div class="amtqty">
#  <div class="markCompanyBlock">
#  								사업자회원만
#  								구매가능
#  							</div>
#  <div class="infoDeli">착불/선결제 <b>2,500</b>원</div> </div>
#  <ul class="subinfo">
#  <li>도매꾹판매</li> </ul>
#  <div class="seller">
#  <div class="nick">
#  <img alt="우수판매자" height="13" src="http://211.43.195.137/image/item/list/ico_goodSeller.png" title="우수판매자" width="17"/>
#  <a href="?sw=juicykat&amp;sf=id">슈퍼통</a>
#  </div>
#  <div class="id">(juicykat)</div> <div class="grade">
#  <b>1</b>등급
#  					</div>
#  <div class="fastdeli">빠른배송</div>
#  </div>
#  </li>, <li>도매꾹판매</li>, <li class="col0 " id="li6373373">
#  <a class="thumb" href="/s/6373373" target="_blank">
#  <img alt="상품이미지" onerror="this.src = 'http://211.43.195.137/image/item/img_notExist330.gif'" src="http://211.43.195.137//upload/item/2015/07/02/14358393305C5D01E73AFBD975872D7C/14358393305C5D01E73AFBD975872D7C_stt_330.png" title="상품이미지"/>
#  </a>
#  <div class="main">
#  <div class="paidIcon">
#  </div>
#  <a class="title" href="/s/6373373" target="_blank">슈퍼통/안경주머니14색상/선글라스케이스안경케이스천</a>
#  </div>
#  <div class="amtqty">
#  <div class="markCompanyBlock">
#  								사업자회원만
#  								구매가능
#  							</div>
#  <div class="infoDeli">착불/선결제 <b>2,500</b>원</div> </div>
#  <ul class="subinfo">
#  <li>도매꾹판매</li> </ul>
#  <div class="seller">
#  <div class="nick">
#  <img alt="우수판매자" height="13" src="http://211.43.195.137/image/item/list/ico_goodSeller.png" title="우수판매자" width="17"/>
#  <a href="?sw=juicykat&amp;sf=id">슈퍼통</a>
#  </div>
#  <div class="id">(juicykat)</div> <div class="grade">
#  <b>1</b>등급
#  					</div>
#  <div class="fastdeli">빠른배송</div>
#  </div>
#  </li>, <li>도매꾹판매</li>, <li class="col1 " id="li3337122">
#  <a class="thumb" href="/s/3337122" target="_blank">
#  <img alt="상품이미지" onerror="this.src = 'http://211.43.195.137/image/item/img_notExist330.gif'" src="http://211.43.195.137//upload/item/2011/09/15/131601501694C31E77F266696896FB61/131601501694C31E77F266696896FB61_stt_330.png" title="상품이미지"/>
#  </a>
#  <div class="main">
#  <div class="paidIcon">
#  </div>
#  <a class="title" href="/s/3337122" target="_blank">[루팡스] 최저가 590원 헤어밴드 반다나 터번 90종</a>
#  </div>
#  <div class="amtqty">
#  <div class="markCompanyBlock">
#  								사업자회원만
#  								구매가능
#  							</div>
#  <div class="infoDeli">선결제 <b>2,500</b>원~</div> </div>
#  <ul class="subinfo">
#  <li>도매꾹판매</li> </ul>
#  <div class="seller">
#  <div class="nick">
#  <img alt="우수판매자" height="13" src="http://211.43.195.137/image/item/list/ico_goodSeller.png" title="우수판매자" width="17"/>
#  <a href="?sw=tjejrduf&amp;sf=id">루팡스</a>
#  </div>
#  <div class="id">(tjejrduf)</div> <div class="grade">
#  <b>1</b>등급
#  					</div>
#  <div class="fastdeli">빠른배송</div>
#  </div>
#  </li>, <li>도매꾹판매</li>, <li class="col2 " id="li5879762">
#  <a class="thumb" href="/s/5879762" target="_blank">
#  <img alt="상품이미지" onerror="this.src = 'http://211.43.195.137/image/item/img_notExist330.gif'" src="http://211.43.195.137//upload/item/2014/04/23/1398180095F07453338AA3474C713E74/1398180095F07453338AA3474C713E74_stt_330.png" title="상품이미지"/>
#  </a>
#  <div class="main">
#  <div class="paidIcon">
#  </div>
#  <a class="title" href="/s/5879762" target="_blank">슈퍼통/100종바니머리끈/헤어밴드머리띠핀바니고무줄</a>
#  </div>
#  <div class="amtqty">
#  <div class="markCompanyBlock">
#  								사업자회원만
#  								구매가능
#  							</div>
#  <div class="infoDeli">착불/선결제 <b>2,500</b>원</div> </div>
#  <ul class="subinfo">
#  <li>도매꾹판매</li> </ul>
#  <div class="seller">
#  <div class="nick">
#  <img alt="우수판매자" height="13" src="http://211.43.195.137/image/item/list/ico_goodSeller.png" title="우수판매자" width="17"/>
#  <a href="?sw=juicykat&amp;sf=id">슈퍼통</a>
#  </div>
#  <div class="id">(juicykat)</div> <div class="grade">
#  <b>1</b>등급
#  					</div>
#  <div class="fastdeli">빠른배송</div>
#  </div>
#  </li>, <li>도매꾹판매</li>, <li class="col3 " id="li7671985">
#  <a class="thumb" href="/s/7671985" target="_blank">
#  <img alt="상품이미지" onerror="this.src = 'http://211.43.195.137/image/item/img_notExist330.gif'" src="http://211.43.195.137//upload/item/2018/01/16/15160949576C9037389C13C82320890D/15160949576C9037389C13C82320890D_stt_330.png" title="상품이미지"/>
#  </a>
#  <div class="main">
#  <div class="paidIcon">
#  </div>
#  <a class="title" href="/s/7671985" target="_blank">[하이뷰] 830/봄신상 여성양말34종/중목/실리콘덧신</a>
#  </div>
#  <div class="amtqty">
#  <div class="markCompanyBlock">
#  								사업자회원만
#  								구매가능
#  							</div>
#  <div class="infoDeli">착불/선결제 <b>2,500</b>원</div> </div>
#  <ul class="subinfo">
#  <li>도매꾹판매</li> </ul>
#  <div class="seller">
#  <div class="nick">
#  <img alt="우수판매자" height="13" src="http://211.43.195.137/image/item/list/ico_goodSeller.png" title="우수판매자" width="17"/><img alt="파워멤버" height="13" src="http://211.43.195.137/image/item/list/ico_powerMember.png" title="파워멤버" width="13"/>
#  <a href="?sw=trendview&amp;sf=id">trendview</a>
#  </div>
#  <div class="grade">
#  <b>1</b>등급
#  					</div>
#  <div class="fastdeli">빠른배송</div>
#  </div>
#  <button class="otherButton" onclick="ToggleSellerItem('#li7671985', 'trendview', 'supply')" target="normal">
#  					판매자의 <b>다른상품</b>
#  </button>
#  <div class="others">
#  <ul></ul>
#  <a href="/main/item/itemList.php?sw=trendview&amp;sf=id" target="_blank">더보기 &gt;</a>
#  </div>
#  </li>, <li>도매꾹판매</li>, <li class="col0 " id="li6989920">
#  <a class="thumb" href="/s/6989920" target="_blank">
#  <img alt="상품이미지" onerror="this.src = 'http://211.43.195.137/image/item/img_notExist330.gif'" src="http://211.43.195.137//upload/item/2016/10/26/147747409367C6F240095446B452C7DE/147747409367C6F240095446B452C7DE_stt_330.png" title="상품이미지"/>
#  </a>
#  <div class="main">
#  <div class="paidIcon">
#  </div>
#  <a class="title" href="/s/6989920" target="_blank">[제이플러스] kc인증 무지파스텔스카프 컬러20종</a>
#  </div>
#  <div class="amtqty">
#  <div class="markCompanyBlock">
#  								사업자회원만
#  								구매가능
#  							</div>
#  <div class="infoDeli">선결제 <b>2,500</b>원~</div> </div>
#  <ul class="subinfo">
#  <li>도매꾹판매</li> </ul>
#  <div class="seller">
#  <div class="nick">
#  <img alt="우수판매자" height="13" src="http://211.43.195.137/image/item/list/ico_goodSeller.png" title="우수판매자" width="17"/><img alt="파워멤버" height="13" src="http://211.43.195.137/image/item/list/ico_powerMember.png" title="파워멤버" width="13"/>
#  <a href="?sw=jplus3753&amp;sf=id">제이플러스1</a>
#  </div>
#  <div class="id">(jplus3753)</div> <div class="grade">
#  <b>1</b>등급
#  					</div>
#  <div class="fastdeli">빠른배송</div>
#  </div>
#  <button class="otherButton" onclick="ToggleSellerItem('#li6989920', 'jplus3753', 'supply')" target="normal">
#  					판매자의 <b>다른상품</b>
#  </button>
#  <div class="others">
#  <ul></ul>
#  <a href="/main/item/itemList.php?sw=jplus3753&amp;sf=id" target="_blank">더보기 &gt;</a>
#  </div>
#  </li>, <li>도매꾹판매</li>, <li class="col1 " id="li7191730">
#  <a class="thumb" href="/s/7191730" target="_blank">
#  <img alt="상품이미지" onerror="this.src = 'http://211.43.195.137/image/item/img_notExist330.gif'" src="http://211.43.195.137//upload/item/2017/04/04/1491232827704774467DC2863689091A/1491232827704774467DC2863689091A_stt_330.png" title="상품이미지"/>
#  </a>
#  <div class="main">
#  <div class="paidIcon">
#  </div>
#  <a class="title" href="/s/7191730" target="_blank">플라즈마 USB 전기라이타 라이터 남성 어버이날 선물</a>
#  </div>
#  <div class="amtqty">
#  <div class="markCompanyBlock">
#  								사업자회원만
#  								구매가능
#  							</div>
#  <div class="infoDeli">착불/선결제 <b>2,500</b>원</div> </div>
#  <ul class="subinfo">
#  <li>도매꾹판매</li> </ul>
#  <div class="seller">
#  <div class="nick">
#  <a href="?sw=seojungkorea&amp;sf=id">서정코리아</a>
#  </div>
#  <div class="id">(seojungkorea)</div> <div class="grade">
#  <b>2</b>등급
#  					</div>
#  <div class="fastdeli">빠른배송</div>
#  </div>
#  </li>, <li>도매꾹판매</li>, <li class="col2 " id="li7755375">
#  <a class="thumb" href="/s/7755375" target="_blank">
#  <img alt="상품이미지" onerror="this.src = 'http://211.43.195.137/image/item/img_notExist330.gif'" src="http://211.43.195.137//upload/item/2018/03/13/1520926562FA9B46912046ED4BC34F12/1520926562FA9B46912046ED4BC34F12_stt_330.png" title="상품이미지"/>
#  </a>
#  <div class="main">
#  <div class="paidIcon">
#  </div>
#  <a class="title" href="/s/7755375" target="_blank">파스텔메리앤집게 /인기절정/빅찬스</a>
#  </div>
#  <div class="amtqty">
#  <div class="markCompanyBlock">
#  								사업자회원만
#  								구매가능
#  							</div>
#  <div class="infoDeli">착불/선결제 <b>2,500</b>원</div> </div>
#  <ul class="subinfo">
#  <li>도매꾹판매</li> </ul>
#  <div class="seller">
#  <div class="nick">
#  <img alt="우수판매자" height="13" src="http://211.43.195.137/image/item/list/ico_goodSeller.png" title="우수판매자" width="17"/>
#  <a href="?sw=jusi2&amp;sf=id">아기자기샵</a>
#  </div>
#  <div class="id">(jusi2)</div> <div class="grade">
#  <b>1</b>등급
#  					</div>
#  </div>
#  <button class="otherButton" onclick="ToggleSellerItem('#li7755375', 'jusi2', 'supply')" target="normal">
#  					판매자의 <b>다른상품</b>
#  </button>
#  <div class="others">
#  <ul></ul>
#  <a href="/main/item/itemList.php?sw=jusi2&amp;sf=id" target="_blank">더보기 &gt;</a>
#  </div>
#  </li>, <li>도매꾹판매</li>, <li class="col3 " id="li5889639">
#  <a class="thumb" href="/s/5889639" target="_blank">
#  <img alt="상품이미지" onerror="this.src = 'http://211.43.195.137/image/item/img_notExist330.gif'" src="http://211.43.195.137//upload/item/2014/04/30/1398856225192E596C8210268E7BCF24/1398856225192E596C8210268E7BCF24_stt_330.png" title="상품이미지"/>
#  </a>
#  <div class="main">
#  <div class="paidIcon">
#  </div>
#  <a class="title" href="/s/5889639" target="_blank">슈퍼통/명품st 선글라스5종/자외선차단패션안경썬캡여</a>
#  </div>
#  <div class="amtqty">
#  <div class="markCompanyBlock">
#  								사업자회원만
#  								구매가능
#  							</div>
#  <div class="infoDeli">착불/선결제 <b>2,500</b>원</div> </div>
#  <ul class="subinfo">
#  <li>도매꾹판매</li> </ul>
#  <div class="seller">
#  <div class="nick">
#  <img alt="우수판매자" height="13" src="http://211.43.195.137/image/item/list/ico_goodSeller.png" title="우수판매자" width="17"/>
#  <a href="?sw=juicykat&amp;sf=id">슈퍼통</a>
#  </div>
#  <div class="id">(juicykat)</div> <div class="grade">
#  <b>1</b>등급
#  					</div>
#  <div class="fastdeli">빠른배송</div>
#  </div>
#  </li>, <li>도매꾹판매</li>, <li class="col0 " id="li7688536">
#  <a class="thumb" href="/s/7688536" target="_blank">
#  <img alt="상품이미지" onerror="this.src = 'http://211.43.195.137/image/item/img_notExist330.gif'" src="http://211.43.195.137//upload/item/2018/01/30/15172817672F93A4ABE19D29540F50F9/15172817672F93A4ABE19D29540F50F9_stt_330.png" title="상품이미지"/>
#  </a>
#  <div class="main">
#  <div class="paidIcon">
#  </div>
#  <a class="title" href="/s/7688536" target="_blank">머리끈 10개씩포장 골드메달 팬던트 아름다운도매</a>
#  </div>
#  <div class="amtqty">
#  <div class="markCompanyBlock">
#  								사업자회원만
#  								구매가능
#  							</div>
#  <div class="infoDeli">선결제</div> </div>
#  <ul class="subinfo">
#  <li>도매꾹판매</li> </ul>
#  <div class="seller">
#  <div class="nick">
#  <img alt="우수판매자" height="13" src="http://211.43.195.137/image/item/list/ico_goodSeller.png" title="우수판매자" width="17"/>
#  <a href="?sw=elchekrits&amp;sf=id">아름다운도매</a>
#  </div>
#  <div class="id">(elchekrits)</div> <div class="grade">
#  <b>1</b>등급
#  					</div>
#  <div class="fastdeli">빠른배송</div>
#  </div>
#  </li>, <li>도매꾹판매</li>, <li class="col1 " id="li5702012">
#  <a class="thumb" href="/s/5702012" target="_blank">
#  <img alt="상품이미지" onerror="this.src = 'http://211.43.195.137/image/item/img_notExist330.gif'" src="http://211.43.195.137//upload/item/2013/09/18/1379480573DF9633158F1D8C1B5295B3/1379480573DF9633158F1D8C1B5295B3_stt_330.png" title="상품이미지"/>
#  </a>
#  <div class="main">
#  <div class="paidIcon">
#  </div>
#  <a class="title" href="/s/5702012" target="_blank">[데이스토리] 유명연예인볼캡/스냅백/모자 (신상입고)</a>
#  </div>
#  <div class="amtqty">
#  <div class="markCompanyBlock">
#  								사업자회원만
#  								구매가능
#  							</div>
#  <div class="infoDeli">착불/선결제 <b>2,500</b>원~</div> </div>
#  <ul class="subinfo">
#  <li>도매꾹판매</li> </ul>
#  <div class="seller">
#  <div class="nick">
#  <img alt="우수판매자" height="13" src="http://211.43.195.137/image/item/list/ico_goodSeller.png" title="우수판매자" width="17"/>
#  <a href="?sw=daystory44&amp;sf=id">데이스토리1</a>
#  </div>
#  <div class="id">(daystory44)</div> <div class="grade">
#  <b>1</b>등급
#  					</div>
#  <div class="fastdeli">빠른배송</div>
#  </div>
#  </li>, <li>도매꾹판매</li>, <li class="col2 " id="li7231250">
#  <a class="thumb" href="/s/7231250" target="_blank">
#  <img alt="상품이미지" onerror="this.src = 'http://211.43.195.137/image/item/img_notExist330.gif'" src="http://211.43.195.137//upload/item/2017/05/16/1494896778DB854C8860B0E25031D7EF/1494896778DB854C8860B0E25031D7EF_stt_330.png" title="상품이미지"/>
#  </a>
#  <div class="main">
#  <div class="paidIcon">
#  </div>
#  <a class="title" href="/s/7231250" target="_blank">골드메달머리끈 헤어밴드 헤어악세사리 헤어끈</a>
#  </div>
#  <div class="amtqty">
#  <div class="markCompanyBlock">
#  								사업자회원만
#  								구매가능
#  							</div>
#  <div class="infoDeli">선결제</div> </div>
#  <ul class="subinfo">
#  <li>도매꾹판매</li> </ul>
#  <div class="seller">
#  <div class="nick">
#  <img alt="우수판매자" height="13" src="http://211.43.195.137/image/item/list/ico_goodSeller.png" title="우수판매자" width="17"/>
#  <a href="?sw=bestmd3&amp;sf=id">부부파이</a>
#  </div>
#  <div class="id">(bestmd3)</div> <div class="grade">
#  <b>1</b>등급
#  					</div>
#  </div>
#  <button class="otherButton" onclick="ToggleSellerItem('#li7231250', 'bestmd3', 'supply')" target="normal">
#  					판매자의 <b>다른상품</b>
#  </button>
#  <div class="others">
#  <ul></ul>
#  <a href="/main/item/itemList.php?sw=bestmd3&amp;sf=id" target="_blank">더보기 &gt;</a>
#  </div>
#  </li>, <li>도매꾹판매</li>, <li class="col3 " id="li7189222">
#  <a class="thumb" href="/s/7189222" target="_blank">
#  <img alt="상품이미지" onerror="this.src = 'http://211.43.195.137/image/item/img_notExist330.gif'" src="http://211.43.195.137//upload/item/2017/04/02/149110997037A454F06AAF8564AE6A21/149110997037A454F06AAF8564AE6A21_stt_330.png" title="상품이미지"/>
#  </a>
#  <div class="main">
#  <div class="paidIcon">
#  </div>
#  <a class="title" href="/s/7189222" target="_blank">실리콘 페이크삭스 남성 여성 덧신 양말 패션 선물 사</a>
#  </div>
#  <div class="amtqty">
#  <div class="markCompanyBlock">
#  								사업자회원만
#  								구매가능
#  							</div>
#  <div class="infoDeli">착불/선결제 <b>2,500</b>원~</div> </div>
#  <ul class="subinfo">
#  <li>도매꾹판매</li> </ul>
#  <div class="seller">
#  <div class="nick">
#  <a href="?sw=seojungkorea&amp;sf=id">서정코리아</a>
#  </div>
#  <div class="id">(seojungkorea)</div> <div class="grade">
#  <b>2</b>등급
#  					</div>
#  <div class="fastdeli">빠른배송</div>
#  </div>
#  </li>, <li>도매꾹판매</li>, <li class="col0 " id="li3181645">
#  <a class="thumb" href="/s/3181645" target="_blank">
#  <img alt="상품이미지" onerror="this.src = 'http://211.43.195.137/image/item/img_notExist330.gif'" src="http://211.43.195.137//upload/item/2011/07/17/1310834412E9A82065C6F06F7563851E/1310834412E9A82065C6F06F7563851E_stt_330.png" title="상품이미지"/>
#  </a>
#  <div class="main">
#  <div class="paidIcon">
#  </div>
#  <a class="title" href="/s/3181645" target="_blank">[루팡스] KC인증 성인/아동/쁘띠/트윌리/무지 스카프</a>
#  </div>
#  <div class="amtqty">
#  <div class="markCompanyBlock">
#  								사업자회원만
#  								구매가능
#  							</div>
#  <div class="infoDeli">선결제 <b>2,500</b>원~</div> </div>
#  <ul class="subinfo">
#  <li>도매꾹판매</li> </ul>
#  <div class="seller">
#  <div class="nick">
#  <img alt="우수판매자" height="13" src="http://211.43.195.137/image/item/list/ico_goodSeller.png" title="우수판매자" width="17"/>
#  <a href="?sw=tjejrduf&amp;sf=id">루팡스</a>
#  </div>
#  <div class="id">(tjejrduf)</div> <div class="grade">
#  <b>1</b>등급
#  					</div>
#  <div class="fastdeli">빠른배송</div>
#  </div>
#  </li>, <li>도매꾹판매</li>, <li class="col1 " id="li7242654">
#  <a class="thumb" href="/s/7242654" target="_blank">
#  <img alt="상품이미지" onerror="this.src = 'http://211.43.195.137/image/item/img_notExist330.gif'" src="http://211.43.195.137//upload/item/2017/05/24/14955936733AECAC4417321859FBEC93/14955936733AECAC4417321859FBEC93_stt_330.png" title="상품이미지"/>
#  </a>
#  <div class="main">
#  <div class="paidIcon">
#  </div>
#  <a class="title" href="/s/7242654" target="_blank">리본장식 썬캡/왕골모자/파나마/라피아/여름모자/썬캡</a>
#  </div>
#  <div class="amtqty">
#  <div class="markCompanyBlock">
#  								사업자회원만
#  								구매가능
#  							</div>
#  <div class="infoDeli">착불/선결제 <b>3,000</b>원~</div> </div>
#  <ul class="subinfo">
#  <li>도매꾹판매</li> </ul>
#  <div class="seller">
#  <div class="nick">
#  <img alt="우수판매자" height="13" src="http://211.43.195.137/image/item/list/ico_goodSeller.png" title="우수판매자" width="17"/><img alt="파워멤버" height="13" src="http://211.43.195.137/image/item/list/ico_powerMember.png" title="파워멤버" width="13"/>
#  <a href="?sw=dreamart&amp;sf=id">드림아트</a>
#  </div>
#  <div class="id">(dreamart)</div> <div class="grade">
#  <b>1</b>등급
#  					</div>
#  <div class="fastdeli">빠른배송</div>
#  </div>
#  <button class="otherButton" onclick="ToggleSellerItem('#li7242654', 'dreamart', 'supply')" target="normal">
#  					판매자의 <b>다른상품</b>
#  </button>
#  <div class="others">
#  <ul></ul>
#  <a href="/main/item/itemList.php?sw=dreamart&amp;sf=id" target="_blank">더보기 &gt;</a>
#  </div>
#  </li>, <li>도매꾹판매</li>, <li class="col2 " id="li7641079">
#  <a class="thumb" href="/s/7641079" target="_blank">
#  <img alt="상품이미지" onerror="this.src = 'http://211.43.195.137/image/item/img_notExist330.gif'" src="http://211.43.195.137//upload/item/2017/12/26/1514286955D635AC62ADDDE4A592BD77/1514286955D635AC62ADDDE4A592BD77_stt_330.png" title="상품이미지"/>
#  </a>
#  <div class="main">
#  <div class="paidIcon">
#  </div>
#  <a class="title" href="/s/7641079" target="_blank">[두리캡]아크릴무지볼캡/야구모자/단체모자/행사모자</a>
#  </div>
#  <div class="amtqty">
#  <div class="markCompanyBlock">
#  								사업자회원만
#  								구매가능
#  							</div>
#  <div class="infoDeli">선결제</div> </div>
#  <ul class="subinfo">
#  <li>도매꾹판매</li> </ul>
#  <div class="seller">
#  <div class="nick">
#  <img alt="우수판매자" height="13" src="http://211.43.195.137/image/item/list/ico_goodSeller.png" title="우수판매자" width="17"/>
#  <a href="?sw=csy5891&amp;sf=id">dooricap</a>
#  </div>
#  <div class="id">(csy5891)</div> <div class="grade">
#  <b>1</b>등급
#  					</div>
#  <div class="fastdeli">빠른배송</div>
#  </div>
#  <button class="otherButton" onclick="ToggleSellerItem('#li7641079', 'csy5891', 'supply')" target="normal">
#  					판매자의 <b>다른상품</b>
#  </button>
#  <div class="others">
#  <ul></ul>
#  <a href="/main/item/itemList.php?sw=csy5891&amp;sf=id" target="_blank">더보기 &gt;</a>
#  </div>
#  </li>, <li>도매꾹판매</li>, <li class="col3 " id="li5965619">
#  <a class="thumb" href="/s/5965619" target="_blank">
#  <img alt="상품이미지" onerror="this.src = 'http://211.43.195.137/image/item/img_notExist330.gif'" src="http://211.43.195.137//upload/item/2014/07/18/140561578011DAFCAE65E58F1B7274CB/140561578011DAFCAE65E58F1B7274CB_stt_330.png" title="상품이미지"/>
#  </a>
#  <div class="main">
#  <div class="paidIcon">
#  </div>
#  <a class="title" href="/s/5965619" target="_blank">슈퍼통/60종엘라스틱헤어타이/밴드머리띠핀바니고무줄</a>
#  </div>
#  <div class="amtqty">
#  <div class="markCompanyBlock">
#  								사업자회원만
#  								구매가능
#  							</div>
#  <div class="infoDeli">착불/선결제 <b>2,500</b>원</div> </div>
#  <ul class="subinfo">
#  <li>도매꾹판매</li> </ul>
#  <div class="seller">
#  <div class="nick">
#  <img alt="우수판매자" height="13" src="http://211.43.195.137/image/item/list/ico_goodSeller.png" title="우수판매자" width="17"/>
#  <a href="?sw=juicykat&amp;sf=id">슈퍼통</a>
#  </div>
#  <div class="id">(juicykat)</div> <div class="grade">
#  <b>1</b>등급
#  					</div>
#  <div class="fastdeli">빠른배송</div>
#  </div>
#  </li>, <li>도매꾹판매</li>, <li class="col0 " id="li6724442">
#  <a class="thumb" href="/s/6724442" target="_blank">
#  <img alt="상품이미지" onerror="this.src = 'http://211.43.195.137/image/item/img_notExist330.gif'" src="http://211.43.195.137//upload/item/2016/03/30/14593207205FC6312338554823F2DE91/14593207205FC6312338554823F2DE91_stt_330.png" title="상품이미지"/>
#  </a>
#  <div class="main">
#  <div class="paidIcon">
#  </div>
#  <a class="title" href="/s/6724442" target="_blank">[월드온]스타킹덧신 페이크삭스 바이오지압 덧신 특가</a>
#  </div>
#  <div class="amtqty">
#  <div class="markCompanyBlock">
#  								사업자회원만
#  								구매가능
#  							</div>
#  <div class="infoDeli">착불/선결제 <b>2,500</b>원~</div> </div>
#  <ul class="subinfo">
#  <li>도매꾹판매</li> </ul>
#  <div class="seller">
#  <div class="nick">
#  <img alt="우수판매자" height="13" src="http://211.43.195.137/image/item/list/ico_goodSeller.png" title="우수판매자" width="17"/><img alt="파워멤버" height="13" src="http://211.43.195.137/image/item/list/ico_powerMember.png" title="파워멤버" width="13"/>
#  <a href="?sw=worldcom&amp;sf=id">월드온</a>
#  </div>
#  <div class="id">(worldcom)</div> <div class="grade">
#  <b>1</b>등급
#  					</div>
#  <div class="fastdeli">빠른배송</div>
#  </div>
#  <button class="otherButton" onclick="ToggleSellerItem('#li6724442', 'worldcom', 'supply')" target="normal">
#  					판매자의 <b>다른상품</b>
#  </button>
#  <div class="others">
#  <ul></ul>
#  <a href="/main/item/itemList.php?sw=worldcom&amp;sf=id" target="_blank">더보기 &gt;</a>
#  </div>
#  </li>, <li>도매꾹판매</li>, <li class="col1 " id="li7771307">
#  <a class="thumb" href="/s/7771307" target="_blank">
#  <img alt="상품이미지" onerror="this.src = 'http://211.43.195.137/image/item/img_notExist330.gif'" src="http://211.43.195.137//upload/item/2018/03/25/1521960223B9992BC2F20C4D316B3C4A/1521960223B9992BC2F20C4D316B3C4A_stt_330.png" title="상품이미지"/>
#  </a>
#  <div class="main">
#  <div class="paidIcon">
#  </div>
#  <a class="title" href="/s/7771307" target="_blank">[다핀]190 큰모자 왕대두 야구모자 빅사이즈 대두볼캡</a>
#  </div>
#  <div class="amtqty">
#  <div class="markCompanyBlock">
#  								사업자회원만
#  								구매가능
#  							</div>
#  <div class="infoDeli">착불/선결제 <b>2,500</b>원~</div> </div>
#  <ul class="subinfo">
#  <li>도매꾹판매</li> </ul>
#  <div class="seller">
#  <div class="nick">
#  <img alt="우수판매자" height="13" src="http://211.43.195.137/image/item/list/ico_goodSeller.png" title="우수판매자" width="17"/>
#  <a href="?sw=daacc56&amp;sf=id">다핀</a>
#  </div>
#  <div class="id">(daacc56)</div> <div class="grade">
#  <b>1</b>등급
#  					</div>
#  <div class="fastdeli">빠른배송</div>
#  </div>
#  <button class="otherButton" onclick="ToggleSellerItem('#li7771307', 'daacc56', 'supply')" target="normal">
#  					판매자의 <b>다른상품</b>
#  </button>
#  <div class="others">
#  <ul></ul>
#  <a href="/main/item/itemList.php?sw=daacc56&amp;sf=id" target="_blank">더보기 &gt;</a>
#  </div>
#  </li>, <li>도매꾹판매</li>, <li class="col2 " id="li6845135">
#  <a class="thumb" href="/s/6845135" target="_blank">
#  <img alt="상품이미지" onerror="this.src = 'http://211.43.195.137/image/item/img_notExist330.gif'" src="http://211.43.195.137//upload/item/2016/06/29/1467188633A5B925FF0F3E51A2CE0B29/1467188633A5B925FF0F3E51A2CE0B29_stt_330.png" title="상품이미지"/>
#  </a>
#  <div class="main">
#  <div class="paidIcon">
#  </div>
#  <a class="title" href="/s/6845135" target="_blank">핑크돼지 비치모자 14종/왕골모자/비치모자/햇빛가리</a>
#  </div>
#  <div class="amtqty">
#  <div class="markCompanyBlock">
#  								사업자회원만
#  								구매가능
#  							</div>
#  <div class="infoDeli">선결제 <b>2,500</b>원~</div> </div>
#  <ul class="subinfo">
#  <li>도매꾹판매</li> </ul>
#  <div class="seller">
#  <div class="nick">
#  <img alt="파워멤버" height="13" src="http://211.43.195.137/image/item/list/ico_powerMember.png" title="파워멤버" width="13"/>
#  <a href="?sw=zzang8314&amp;sf=id">핑크돼지1</a>
#  </div>
#  <div class="id">(zzang8314)</div> <div class="grade">
#  <b>1</b>등급
#  					</div>
#  </div>
#  <button class="otherButton" onclick="ToggleSellerItem('#li6845135', 'zzang8314', 'supply')" target="normal">
#  					판매자의 <b>다른상품</b>
#  </button>
#  <div class="others">
#  <ul></ul>
#  <a href="/main/item/itemList.php?sw=zzang8314&amp;sf=id" target="_blank">더보기 &gt;</a>
#  </div>
#  </li>, <li>도매꾹판매</li>, <li class="col3 " id="li6274962">
#  <a class="thumb" href="/s/6274962" target="_blank">
#  <img alt="상품이미지" onerror="this.src = 'http://211.43.195.137/image/item/img_notExist330.gif'" src="http://211.43.195.137//upload/item/2015/05/08/14310788312263E3DEE3FC921BC710B5/14310788312263E3DEE3FC921BC710B5_stt_330.png" title="상품이미지"/>
#  </a>
#  <div class="main">
#  <div class="paidIcon">
#  </div>
#  <a class="title" href="/s/6274962" target="_blank">미러선글라스 13종/KC인증/선글라스/미러/바캉스준비</a>
#  </div>
#  <div class="amtqty">
#  <div class="markCompanyBlock">
#  								사업자회원만
#  								구매가능
#  							</div>
#  <div class="infoDeli">선결제 <b>2,500</b>원~</div> </div>
#  <ul class="subinfo">
#  <li>도매꾹판매</li> </ul>
#  <div class="seller">
#  <div class="nick">
#  <img alt="파워멤버" height="13" src="http://211.43.195.137/image/item/list/ico_powerMember.png" title="파워멤버" width="13"/>
#  <a href="?sw=zzang8314&amp;sf=id">핑크돼지1</a>
#  </div>
#  <div class="id">(zzang8314)</div> <div class="grade">
#  <b>1</b>등급
#  					</div>
#  </div>
#  <button class="otherButton" onclick="ToggleSellerItem('#li6274962', 'zzang8314', 'supply')" target="normal">
#  					판매자의 <b>다른상품</b>
#  </button>
#  <div class="others">
#  <ul></ul>
#  <a href="/main/item/itemList.php?sw=zzang8314&amp;sf=id" target="_blank">더보기 &gt;</a>
#  </div>
#  </li>, <li>도매꾹판매</li>, <li class="col0 " id="li1593057">
#  <a class="thumb" href="/s/1593057" target="_blank">
#  <img alt="상품이미지" onerror="this.src = 'http://211.43.195.137/image/item/img_notExist330.gif'" src="http://211.43.195.137//upload/item/2009/04/23/1240464898F40CCCD9A3E66527AC73C6/1240464898F40CCCD9A3E66527AC73C6_stt_330.png" title="상품이미지"/>
#  </a>
#  <div class="main">
#  <div class="paidIcon">
#  </div>
#  <a class="title" href="/s/1593057" target="_blank">[다핀]24 신상 24칼라 민자고무줄 머리끈 칼라고무줄</a>
#  </div>
#  <div class="amtqty">
#  <div class="markCompanyBlock">
#  								사업자회원만
#  								구매가능
#  							</div>
#  <div class="infoDeli">착불/선결제 <b>2,500</b>원~</div> </div>
#  <ul class="subinfo">
#  <li>도매꾹판매</li> </ul>
#  <div class="seller">
#  <div class="nick">
#  <img alt="우수판매자" height="13" src="http://211.43.195.137/image/item/list/ico_goodSeller.png" title="우수판매자" width="17"/>
#  <a href="?sw=daacc56&amp;sf=id">다핀</a>
#  </div>
#  <div class="id">(daacc56)</div> <div class="grade">
#  <b>1</b>등급
#  					</div>
#  <div class="fastdeli">빠른배송</div>
#  </div>
#  <button class="otherButton" onclick="ToggleSellerItem('#li1593057', 'daacc56', 'supply')" target="normal">
#  					판매자의 <b>다른상품</b>
#  </button>
#  <div class="others">
#  <ul></ul>
#  <a href="/main/item/itemList.php?sw=daacc56&amp;sf=id" target="_blank">더보기 &gt;</a>
#  </div>
#  </li>, <li>도매꾹판매</li>, <li class="col1 " id="li5879767">
#  <a class="thumb" href="/s/5879767" target="_blank">
#  <img alt="상품이미지" onerror="this.src = 'http://211.43.195.137/image/item/img_notExist330.gif'" src="http://211.43.195.137//upload/item/2014/04/23/1398182688D156777442A5C6F6F095D9/1398182688D156777442A5C6F6F095D9_stt_330.png" title="상품이미지"/>
#  </a>
#  <div class="main">
#  <div class="paidIcon">
#  </div>
#  <a class="title" href="/s/5879767" target="_blank">슈퍼통/162종토끼귀곱창머리끈/헤어밴드머리띠핀바니</a>
#  </div>
#  <div class="amtqty">
#  <div class="markCompanyBlock">
#  								사업자회원만
#  								구매가능
#  							</div>
#  <div class="infoDeli">착불/선결제 <b>2,500</b>원</div> </div>
#  <ul class="subinfo">
#  <li>도매꾹판매</li> </ul>
#  <div class="seller">
#  <div class="nick">
#  <img alt="우수판매자" height="13" src="http://211.43.195.137/image/item/list/ico_goodSeller.png" title="우수판매자" width="17"/>
#  <a href="?sw=juicykat&amp;sf=id">슈퍼통</a>
#  </div>
#  <div class="id">(juicykat)</div> <div class="grade">
#  <b>1</b>등급
#  					</div>
#  <div class="fastdeli">빠른배송</div>
#  </div>
#  </li>, <li>도매꾹판매</li>, <li class="col2 " id="li6774972">
#  <a class="thumb" href="/s/6774972" target="_blank">
#  <img alt="상품이미지" onerror="this.src = 'http://211.43.195.137/image/item/img_notExist330.gif'" src="http://211.43.195.137//upload/item/2016/05/04/14623428002F3D188CCBEA8ABD884ED4/14623428002F3D188CCBEA8ABD884ED4_stt_330.png" title="상품이미지"/>
#  </a>
#  <div class="main">
#  <div class="paidIcon">
#  </div>
#  <a class="title" href="/s/6774972" target="_blank">[다핀]500신상 5칼라 매듭없는 고무줄 머리끈</a>
#  </div>
#  <div class="amtqty">
#  <div class="markCompanyBlock">
#  								사업자회원만
#  								구매가능
#  							</div>
#  <div class="infoDeli">착불/선결제 <b>2,500</b>원~</div> </div>
#  <ul class="subinfo">
#  <li>도매꾹판매</li> </ul>
#  <div class="seller">
#  <div class="nick">
#  <img alt="우수판매자" height="13" src="http://211.43.195.137/image/item/list/ico_goodSeller.png" title="우수판매자" width="17"/>
#  <a href="?sw=daacc56&amp;sf=id">다핀</a>
#  </div>
#  <div class="id">(daacc56)</div> <div class="grade">
#  <b>1</b>등급
#  					</div>
#  <div class="fastdeli">빠른배송</div>
#  </div>
#  <button class="otherButton" onclick="ToggleSellerItem('#li6774972', 'daacc56', 'supply')" target="normal">
#  					판매자의 <b>다른상품</b>
#  </button>
#  <div class="others">
#  <ul></ul>
#  <a href="/main/item/itemList.php?sw=daacc56&amp;sf=id" target="_blank">더보기 &gt;</a>
#  </div>
#  </li>, <li>도매꾹판매</li>, <li class="col3 " id="li7206072">
#  <a class="thumb" href="/s/7206072" target="_blank">
#  <img alt="상품이미지" onerror="this.src = 'http://211.43.195.137/image/item/img_notExist330.gif'" src="http://211.43.195.137//upload/item/2017/04/17/149240397099ED5F1543FA209C8A049E/149240397099ED5F1543FA209C8A049E_stt_330.png" title="상품이미지"/>
#  </a>
#  <div class="main">
#  <div class="paidIcon">
#  </div>
#  <a class="title" href="/s/7206072" target="_blank">[마이도매]최저가 71종 다양한 돌돌이모자/지속공급/</a>
#  </div>
#  <div class="amtqty">
#  <div class="markCompanyBlock">
#  								사업자회원만
#  								구매가능
#  							</div>
#  <div class="infoDeli">선결제 <b>2,500</b>원~</div> </div>
#  <ul class="subinfo">
#  <li>도매꾹판매</li> </ul>
#  <div class="seller">
#  <div class="nick">
#  <img alt="파워멤버" height="13" src="http://211.43.195.137/image/item/list/ico_powerMember.png" title="파워멤버" width="13"/>
#  <a href="?sw=ozzshop&amp;sf=id">마이도매몰</a>
#  </div>
#  <div class="id">(ozzshop)</div> <div class="grade">
#  <b>1</b>등급
#  					</div>
#  <div class="fastdeli">빠른배송</div>
#  </div>
#  <button class="otherButton" onclick="ToggleSellerItem('#li7206072', 'ozzshop', 'supply')" target="normal">
#  					판매자의 <b>다른상품</b>
#  </button>
#  <div class="others">
#  <ul></ul>
#  <a href="/main/item/itemList.php?sw=ozzshop&amp;sf=id" target="_blank">더보기 &gt;</a>
#  </div>
#  </li>, <li>도매꾹판매</li>, <li class="col0 " id="li5956623">
#  <a class="thumb" href="/s/5956623" target="_blank">
#  <img alt="상품이미지" onerror="this.src = 'http://211.43.195.137/image/item/img_notExist330.gif'" src="http://211.43.195.137//upload/item/2014/07/08/1404831453D597797DA01054BECB40C5/1404831453D597797DA01054BECB40C5_stt_330.png" title="상품이미지"/>
#  </a>
#  <div class="main">
#  <div class="paidIcon">
#  </div>
#  <a class="title" href="/s/5956623" target="_blank">슈퍼통/미러선글라스9종/자외선차단안경썬캡여름여행</a>
#  </div>
#  <div class="amtqty">
#  <div class="markCompanyBlock">
#  								사업자회원만
#  								구매가능
#  							</div>
#  <div class="infoDeli">착불/선결제 <b>2,500</b>원</div> </div>
#  <ul class="subinfo">
#  <li>도매꾹판매</li> </ul>
#  <div class="seller">
#  <div class="nick">
#  <img alt="우수판매자" height="13" src="http://211.43.195.137/image/item/list/ico_goodSeller.png" title="우수판매자" width="17"/>
#  <a href="?sw=juicykat&amp;sf=id">슈퍼통</a>
#  </div>
#  <div class="id">(juicykat)</div> <div class="grade">
#  <b>1</b>등급
#  					</div>
#  <div class="fastdeli">빠른배송</div>
#  </div>
#  </li>, <li>도매꾹판매</li>, <li class="col1 " id="li6071443">
#  <a class="thumb" href="/s/6071443" target="_blank">
#  <img alt="상품이미지" onerror="this.src = 'http://211.43.195.137/image/item/img_notExist330.gif'" src="http://211.43.195.137//upload/item/2014/11/13/141588674386D6D09199316290A3B2A4/141588674386D6D09199316290A3B2A4_stt_330.png" title="상품이미지"/>
#  </a>
#  <div class="main">
#  <div class="paidIcon">
#  </div>
#  <a class="title" href="/s/6071443" target="_blank">슈퍼통/골드메달캔디머리끈/헤어밴드머리띠핀바니고무</a>
#  </div>
#  <div class="amtqty">
#  <div class="markCompanyBlock">
#  								사업자회원만
#  								구매가능
#  							</div>
#  <div class="infoDeli">착불/선결제 <b>2,500</b>원</div> </div>
#  <ul class="subinfo">
#  <li>도매꾹판매</li> </ul>
#  <div class="seller">
#  <div class="nick">
#  <img alt="우수판매자" height="13" src="http://211.43.195.137/image/item/list/ico_goodSeller.png" title="우수판매자" width="17"/>
#  <a href="?sw=juicykat&amp;sf=id">슈퍼통</a>
#  </div>
#  <div class="id">(juicykat)</div> <div class="grade">
#  <b>1</b>등급
#  					</div>
#  <div class="fastdeli">빠른배송</div>
#  </div>
#  </li>, <li>도매꾹판매</li>, <li class="col2 " id="li7291278">
#  <a class="thumb" href="/s/7291278" target="_blank">
#  <img alt="상품이미지" onerror="this.src = 'http://211.43.195.137/image/item/img_notExist330.gif'" src="http://211.43.195.137//upload/item/2017/06/27/1498537726CC49B0A006E3AAF61A2B8E/1498537726CC49B0A006E3AAF61A2B8E_stt_330.png" title="상품이미지"/>
#  </a>
#  <div class="main">
#  <div class="paidIcon">
#  </div>
#  <a class="title" href="/s/7291278" target="_blank">[루키]3단우산 접이식우산 패턴우산 양산겸용우산</a>
#  </div>
#  <div class="amtqty">
#  <div class="markCompanyBlock">
#  								사업자회원만
#  								구매가능
#  							</div>
#  <div class="infoDeli">선결제 <b>3,000</b>원</div> </div>
#  <ul class="subinfo">
#  <li>도매꾹판매</li> </ul>
#  <div class="seller">
#  <div class="nick">
#  <img alt="우수판매자" height="13" src="http://211.43.195.137/image/item/list/ico_goodSeller.png" title="우수판매자" width="17"/><img alt="파워멤버" height="13" src="http://211.43.195.137/image/item/list/ico_powerMember.png" title="파워멤버" width="13"/>
#  <a href="?sw=elja&amp;sf=id">루키</a>
#  </div>
#  <div class="id">(elja)</div> <div class="grade">
#  <b>1</b>등급
#  					</div>
#  <div class="fastdeli">빠른배송</div>
#  </div>
#  <button class="otherButton" onclick="ToggleSellerItem('#li7291278', 'elja', 'supply')" target="normal">
#  					판매자의 <b>다른상품</b>
#  </button>
#  <div class="others">
#  <ul></ul>
#  <a href="/main/item/itemList.php?sw=elja&amp;sf=id" target="_blank">더보기 &gt;</a>
#  </div>
#  </li>, <li>도매꾹판매</li>, <li class="col3 " id="li7628562">
#  <a class="thumb" href="/s/7628562" target="_blank">
#  <img alt="상품이미지" onerror="this.src = 'http://211.43.195.137/image/item/img_notExist330.gif'" src="http://211.43.195.137//upload/item/2017/12/18/1513566425327104B114D379090628E2/1513566425327104B114D379090628E2_stt_330.png" title="상품이미지"/>
#  </a>
#  <div class="main">
#  <div class="paidIcon">
#  </div>
#  <a class="title" href="/s/7628562" target="_blank">메리앤리본핀/인기짱/590원</a>
#  </div>
#  <div class="amtqty">
#  <div class="markCompanyBlock">
#  								사업자회원만
#  								구매가능
#  							</div>
#  <div class="infoDeli">착불/선결제 <b>2,500</b>원</div> </div>
#  <ul class="subinfo">
#  <li>도매꾹판매</li> </ul>
#  <div class="seller">
#  <div class="nick">
#  <img alt="우수판매자" height="13" src="http://211.43.195.137/image/item/list/ico_goodSeller.png" title="우수판매자" width="17"/>
#  <a href="?sw=jusi2&amp;sf=id">아기자기샵</a>
#  </div>
#  <div class="id">(jusi2)</div> <div class="grade">
#  <b>1</b>등급
#  					</div>
#  </div>
#  <button class="otherButton" onclick="ToggleSellerItem('#li7628562', 'jusi2', 'supply')" target="normal">
#  					판매자의 <b>다른상품</b>
#  </button>
#  <div class="others">
#  <ul></ul>
#  <a href="/main/item/itemList.php?sw=jusi2&amp;sf=id" target="_blank">더보기 &gt;</a>
#  </div>
#  </li>, <li>도매꾹판매</li>, <li class="col0 " id="li7247935">
#  <a class="thumb" href="/s/7247935" target="_blank">
#  <img alt="상품이미지" onerror="this.src = 'http://211.43.195.137/image/item/img_notExist330.gif'" src="http://211.43.195.137//upload/item/2017/05/29/149604258022F43EBFEBE739D04DF6E7/149604258022F43EBFEBE739D04DF6E7_stt_330.png" title="상품이미지"/>
#  </a>
#  <div class="main">
#  <div class="paidIcon">
#  </div>
#  <a class="title" href="/s/7247935" target="_blank">핑크돼지 청담모자/왕골모자/햇빛가리개모자/버킷햇/</a>
#  </div>
#  <div class="amtqty">
#  <div class="markCompanyBlock">
#  								사업자회원만
#  								구매가능
#  							</div>
#  <div class="infoDeli">선결제 <b>2,500</b>원~</div> </div>
#  <ul class="subinfo">
#  <li>도매꾹판매</li> </ul>
#  <div class="seller">
#  <div class="nick">
#  <img alt="파워멤버" height="13" src="http://211.43.195.137/image/item/list/ico_powerMember.png" title="파워멤버" width="13"/>
#  <a href="?sw=zzang8314&amp;sf=id">핑크돼지1</a>
#  </div>
#  <div class="id">(zzang8314)</div> <div class="grade">
#  <b>1</b>등급
#  					</div>
#  </div>
#  <button class="otherButton" onclick="ToggleSellerItem('#li7247935', 'zzang8314', 'supply')" target="normal">
#  					판매자의 <b>다른상품</b>
#  </button>
#  <div class="others">
#  <ul></ul>
#  <a href="/main/item/itemList.php?sw=zzang8314&amp;sf=id" target="_blank">더보기 &gt;</a>
#  </div>
#  </li>, <li>도매꾹판매</li>, <li class="col1 " id="li6947675">
#  <a class="thumb" href="/s/6947675" target="_blank">
#  <img alt="상품이미지" onerror="this.src = 'http://211.43.195.137/image/item/img_notExist330.gif'" src="http://211.43.195.137//upload/item/2016/09/22/147452783000D6F6FCF2E4911963BFB6/147452783000D6F6FCF2E4911963BFB6_stt_330.png" title="상품이미지"/>
#  </a>
#  <div class="main">
#  <div class="paidIcon">
#  </div>
#  <a class="title" href="/s/6947675" target="_blank">[에스디몰]로맨틱실크쁘띠스카프/공단실크/사각스카프</a>
#  </div>
#  <div class="amtqty">
#  <div class="markCompanyBlock">
#  								사업자회원만
#  								구매가능
#  							</div>
#  <div class="infoDeli">선결제 <b>2,500</b>원~</div> </div>
#  <ul class="subinfo">
#  <li>도매꾹판매</li> </ul>
#  <div class="seller">
#  <div class="nick">
#  <img alt="우수판매자" height="13" src="http://211.43.195.137/image/item/list/ico_goodSeller.png" title="우수판매자" width="17"/><img alt="파워멤버" height="13" src="http://211.43.195.137/image/item/list/ico_powerMember.png" title="파워멤버" width="13"/>
#  <a href="?sw=escata&amp;sf=id">에스디몰</a>
#  </div>
#  <div class="id">(escata)</div> <div class="grade">
#  <b>1</b>등급
#  					</div>
#  </div>
#  <button class="otherButton" onclick="ToggleSellerItem('#li6947675', 'escata', 'supply')" target="normal">
#  					판매자의 <b>다른상품</b>
#  </button>
#  <div class="others">
#  <ul></ul>
#  <a href="/main/item/itemList.php?sw=escata&amp;sf=id" target="_blank">더보기 &gt;</a>
#  </div>
#  </li>, <li>도매꾹판매</li>, <li class="col2 " id="li7367147">
#  <a class="thumb" href="/s/7367147" target="_blank">
#  <img alt="상품이미지" onerror="this.src = 'http://211.43.195.137/image/item/img_notExist330.gif'" src="http://211.43.195.137//upload/item/2017/07/30/1501423152316678282AA6955C6F4F89/1501423152316678282AA6955C6F4F89_stt_330.png" title="상품이미지"/>
#  </a>
#  <div class="main">
#  <div class="paidIcon">
#  </div>
#  <a class="title" href="/s/7367147" target="_blank">[백상]페이크삭스/양말/실리콘처리/발목양말/덧신</a>
#  </div>
#  <div class="amtqty">
#  <div class="markCompanyBlock">
#  								사업자회원만
#  								구매가능
#  							</div>
#  <div class="infoDeli">선결제 <b>2,500</b>원~</div> </div>
#  <ul class="subinfo">
#  <li>도매꾹판매</li> </ul>
#  <div class="seller">
#  <div class="nick">
#  <img alt="우수판매자" height="13" src="http://211.43.195.137/image/item/list/ico_goodSeller.png" title="우수판매자" width="17"/><img alt="파워멤버" height="13" src="http://211.43.195.137/image/item/list/ico_powerMember.png" title="파워멤버" width="13"/>
#  <a href="?sw=jcgjc35&amp;sf=id">또니하트</a>
#  </div>
#  <div class="id">(jcgjc35)</div> <div class="grade">
#  <b>1</b>등급
#  					</div>
#  <div class="fastdeli">빠른배송</div>
#  </div>
#  <button class="otherButton" onclick="ToggleSellerItem('#li7367147', 'jcgjc35', 'supply')" target="normal">
#  					판매자의 <b>다른상품</b>
#  </button>
#  <div class="others">
#  <ul></ul>
#  <a href="/main/item/itemList.php?sw=jcgjc35&amp;sf=id" target="_blank">더보기 &gt;</a>
#  </div>
#  </li>, <li>도매꾹판매</li>, <li class="col3 " id="li7751632">
#  <a class="thumb" href="/s/7751632" target="_blank">
#  <img alt="상품이미지" onerror="this.src = 'http://211.43.195.137/image/item/img_notExist330.gif'" src="http://211.43.195.137//upload/item/2018/03/12/152081869171A4CFEF8495B3FDADE042/152081869171A4CFEF8495B3FDADE042_stt_330.png" title="상품이미지"/>
#  </a>
#  <div class="main">
#  <div class="paidIcon">
#  </div>
#  <a class="title" href="/s/7751632" target="_blank">남성용/여성용 최고급 페이크삭스/발목 양말/실리콘</a>
#  </div>
#  <div class="amtqty">
#  <div class="markCompanyBlock">
#  								사업자회원만
#  								구매가능
#  							</div>
#  <div class="infoDeli">선결제 <b>2,500</b>원</div> </div>
#  <ul class="subinfo">
#  <li>도매꾹판매</li> </ul>
#  <div class="seller">
#  <div class="nick">
#  <img alt="우수판매자" height="13" src="http://211.43.195.137/image/item/list/ico_goodSeller.png" title="우수판매자" width="17"/>
#  <a href="?sw=bestmd3&amp;sf=id">부부파이</a>
#  </div>
#  <div class="id">(bestmd3)</div> <div class="grade">
#  <b>1</b>등급
#  					</div>
#  </div>
#  <button class="otherButton" onclick="ToggleSellerItem('#li7751632', 'bestmd3', 'supply')" target="normal">
#  					판매자의 <b>다른상품</b>
#  </button>
#  <div class="others">
#  <ul></ul>
#  <a href="/main/item/itemList.php?sw=bestmd3&amp;sf=id" target="_blank">더보기 &gt;</a>
#  </div>
#  </li>, <li>도매꾹판매</li>, <li class="col0 " id="li1551572">
#  <a class="thumb" href="/s/1551572" target="_blank">
#  <img alt="상품이미지" onerror="this.src = 'http://211.43.195.137/image/item/img_notExist330.gif'" src="http://211.43.195.137//upload/item/2009/03/10/1236666115AED5059028D9AB8CD55DA8/1236666115AED5059028D9AB8CD55DA8_stt_330.png" title="상품이미지"/>
#  </a>
#  <div class="main">
#  <div class="paidIcon">
#  </div>
#  <a class="title" href="/s/1551572" target="_blank">[다핀]100 신상 캐릭터 모티브 검정 칼라 형광 팔찌겸</a>
#  </div>
#  <div class="amtqty">
#  <div class="markCompanyBlock">
#  								사업자회원만
#  								구매가능
#  							</div>
#  <div class="infoDeli">착불/선결제 <b>2,500</b>원</div> </div>
#  <ul class="subinfo">
#  <li>도매꾹판매</li> </ul>
#  <div class="seller">
#  <div class="nick">
#  <img alt="우수판매자" height="13" src="http://211.43.195.137/image/item/list/ico_goodSeller.png" title="우수판매자" width="17"/>
#  <a href="?sw=daacc56&amp;sf=id">다핀</a>
#  </div>
#  <div class="id">(daacc56)</div> <div class="grade">
#  <b>1</b>등급
#  					</div>
#  <div class="fastdeli">빠른배송</div>
#  </div>
#  <button class="otherButton" onclick="ToggleSellerItem('#li1551572', 'daacc56', 'supply')" target="normal">
#  					판매자의 <b>다른상품</b>
#  </button>
#  <div class="others">
#  <ul></ul>
#  <a href="/main/item/itemList.php?sw=daacc56&amp;sf=id" target="_blank">더보기 &gt;</a>
#  </div>
#  </li>, <li>도매꾹판매</li>, <li class="col1 " id="li7761080">
#  <a class="thumb" href="/s/7761080" target="_blank">
#  <img alt="상품이미지" onerror="this.src = 'http://211.43.195.137/image/item/img_notExist330.gif'" src="http://211.43.195.137//upload/item/2018/03/18/1521349336B30F877C70A58503ADE3EC/1521349336B30F877C70A58503ADE3EC_stt_330.png" title="상품이미지"/>
#  </a>
#  <div class="main">
#  <div class="paidIcon">
#  </div>
#  <a class="title" href="/s/7761080" target="_blank">정품리버티원단똑딱핀/인기짱</a>
#  </div>
#  <div class="amtqty">
#  <div class="markCompanyBlock">
#  								사업자회원만
#  								구매가능
#  							</div>
#  <div class="infoDeli">착불/선결제 <b>2,500</b>원</div> </div>
#  <ul class="subinfo">
#  <li>도매꾹판매</li> </ul>
#  <div class="seller">
#  <div class="nick">
#  <img alt="우수판매자" height="13" src="http://211.43.195.137/image/item/list/ico_goodSeller.png" title="우수판매자" width="17"/>
#  <a href="?sw=jusi2&amp;sf=id">아기자기샵</a>
#  </div>
#  <div class="id">(jusi2)</div> <div class="grade">
#  <b>1</b>등급
#  					</div>
#  </div>
#  <button class="otherButton" onclick="ToggleSellerItem('#li7761080', 'jusi2', 'supply')" target="normal">
#  					판매자의 <b>다른상품</b>
#  </button>
#  <div class="others">
#  <ul></ul>
#  <a href="/main/item/itemList.php?sw=jusi2&amp;sf=id" target="_blank">더보기 &gt;</a>
#  </div>
#  </li>, <li>도매꾹판매</li>, <li class="col2 " id="li7517032">
#  <a class="thumb" href="/s/7517032" target="_blank">
#  <img alt="상품이미지" onerror="this.src = 'http://211.43.195.137/image/item/img_notExist330.gif'" src="http://211.43.195.137//upload/item/2017/11/06/15099426712B8728B4E8DD0E6B845257/15099426712B8728B4E8DD0E6B845257_stt_330.png" title="상품이미지"/>
#  </a>
#  <div class="main">
#  <div class="paidIcon">
#  </div>
#  <a class="title" href="/s/7517032" target="_blank">트위스트 머리끈/꼬임팔찌/머리끈/헤어끈/헤어링/패션</a>
#  </div>
#  <div class="amtqty">
#  <div class="markCompanyBlock">
#  								사업자회원만
#  								구매가능
#  							</div>
#  <div class="infoDeli">선결제 <b>2,500</b>원</div> </div>
#  <ul class="subinfo">
#  <li>도매꾹판매</li> </ul>
#  <div class="seller">
#  <div class="nick">
#  <img alt="우수판매자" height="13" src="http://211.43.195.137/image/item/list/ico_goodSeller.png" title="우수판매자" width="17"/><img alt="파워멤버" height="13" src="http://211.43.195.137/image/item/list/ico_powerMember.png" title="파워멤버" width="13"/>
#  <a href="?sw=lns00720&amp;sf=id">파스텔하우스</a>
#  </div>
#  <div class="id">(lns00720)</div> <div class="grade">
#  <b>1</b>등급
#  					</div>
#  <div class="fastdeli">빠른배송</div>
#  </div>
#  <button class="otherButton" onclick="ToggleSellerItem('#li7517032', 'lns00720', 'supply')" target="normal">
#  					판매자의 <b>다른상품</b>
#  </button>
#  <div class="others">
#  <ul></ul>
#  <a href="/main/item/itemList.php?sw=lns00720&amp;sf=id" target="_blank">더보기 &gt;</a>
#  </div>
#  </li>, <li>도매꾹판매</li>, <li class="col3 " id="li7423544">
#  <a class="thumb" href="/s/7423544" target="_blank">
#  <img alt="상품이미지" onerror="this.src = 'http://211.43.195.137/image/item/img_notExist330.gif'" src="http://211.43.195.137//upload/item/2017/08/31/150414577912254146442CB56CFA147E/150414577912254146442CB56CFA147E_stt_330.png" title="상품이미지"/>
#  </a>
#  <div class="main">
#  <div class="paidIcon">
#  </div>
#  <a class="title" href="/s/7423544" target="_blank">헤어핀 큐빅핀 악세사리 머리핀 집게핀 올림머리핀</a>
#  </div>
#  <div class="amtqty">
#  <div class="markCompanyBlock">
#  								사업자회원만
#  								구매가능
#  							</div>
#  <div class="infoDeli">선결제 <b>2,500</b>원~</div> </div>
#  <ul class="subinfo">
#  <li>도매꾹판매</li> </ul>
#  <div class="seller">
#  <div class="nick">
#  <a href="?sw=lsh2566&amp;sf=id">다팔자코리아</a>
#  </div>
#  <div class="id">(lsh2566)</div> <div class="grade">
#  <b>1</b>등급
#  					</div>
#  </div>
#  </li>, <li>도매꾹판매</li>, <li class="col0 " id="li7272760">
#  <a class="thumb" href="/s/7272760" target="_blank">
#  <img alt="상품이미지" onerror="this.src = 'http://211.43.195.137/image/item/img_notExist330.gif'" src="http://211.43.195.137//upload/item/2017/06/13/1497332838DCF8FF6706051D368E12A3/1497332838DCF8FF6706051D368E12A3_stt_330.png" title="상품이미지"/>
#  </a>
#  <div class="main">
#  <div class="paidIcon">
#  </div>
#  <a class="title" href="/s/7272760" target="_blank">핑크돼지 반다나일체형28종모음/반다나/머리끈/헤어밴</a>
#  </div>
#  <div class="amtqty">
#  <div class="markCompanyBlock">
#  								사업자회원만
#  								구매가능
#  							</div>
#  <div class="infoDeli">선결제 <b>2,500</b>원~</div> </div>
#  <ul class="subinfo">
#  <li>도매꾹판매</li> </ul>
#  <div class="seller">
#  <div class="nick">
#  <img alt="파워멤버" height="13" src="http://211.43.195.137/image/item/list/ico_powerMember.png" title="파워멤버" width="13"/>
#  <a href="?sw=zzang8314&amp;sf=id">핑크돼지1</a>
#  </div>
#  <div class="id">(zzang8314)</div> <div class="grade">
#  <b>1</b>등급
#  					</div>
#  </div>
#  <button class="otherButton" onclick="ToggleSellerItem('#li7272760', 'zzang8314', 'supply')" target="normal">
#  					판매자의 <b>다른상품</b>
#  </button>
#  <div class="others">
#  <ul></ul>
#  <a href="/main/item/itemList.php?sw=zzang8314&amp;sf=id" target="_blank">더보기 &gt;</a>
#  </div>
#  </li>, <li>도매꾹판매</li>, <li class="col1 " id="li5547697">
#  <a class="thumb" href="/s/5547697" target="_blank">
#  <img alt="상품이미지" onerror="this.src = 'http://211.43.195.137/image/item/img_notExist330.gif'" src="http://211.43.195.137//upload/item/2013/02/28/13619874722B311A2D060B83BFAE7D7D/13619874722B311A2D060B83BFAE7D7D_stt_330.png" title="상품이미지"/>
#  </a>
#  <div class="main">
#  <div class="paidIcon">
#  </div>
#  <a class="title" href="/s/5547697" target="_blank">스타일도매 가을신상 청레깅스/왕스판레깅스/치마레깅</a>
#  </div>
#  <div class="amtqty">
#  <div class="markCompanyBlock">
#  								사업자회원만
#  								구매가능
#  							</div>
#  <div class="infoDeli">착불/선결제 <b>2,500</b>원</div> </div>
#  <ul class="subinfo">
#  <li>도매꾹판매</li> </ul>
#  <div class="seller">
#  <div class="nick">
#  <a href="?sw=skyxmen&amp;sf=id">스타일도매</a>
#  </div>
#  <div class="id">(skyxmen)</div> <div class="grade">
#  <b>1</b>등급
#  					</div>
#  <div class="fastdeli">빠른배송</div>
#  </div>
#  </li>, <li>도매꾹판매</li>, <li class="col2 " id="li6842215">
#  <a class="thumb" href="/s/6842215" target="_blank">
#  <img alt="상품이미지" onerror="this.src = 'http://211.43.195.137/image/item/img_notExist330.gif'" src="http://211.43.195.137//upload/item/2016/06/27/1467004118616348D9D716CB82293806/1467004118616348D9D716CB82293806_stt_330.png" title="상품이미지"/>
#  </a>
#  <div class="main">
#  <div class="paidIcon">
#  </div>
#  <a class="title" href="/s/6842215" target="_blank">핑크돼지 360도썬캡/썬캡/모자/햇빛가리개/선캡/등산</a>
#  </div>
#  <div class="amtqty">
#  <div class="markCompanyBlock">
#  								사업자회원만
#  								구매가능
#  							</div>
#  <div class="infoDeli">선결제 <b>2,500</b>원~</div> </div>
#  <ul class="subinfo">
#  <li>도매꾹판매</li> </ul>
#  <div class="seller">
#  <div class="nick">
#  <img alt="파워멤버" height="13" src="http://211.43.195.137/image/item/list/ico_powerMember.png" title="파워멤버" width="13"/>
#  <a href="?sw=zzang8314&amp;sf=id">핑크돼지1</a>
#  </div>
#  <div class="id">(zzang8314)</div> <div class="grade">
#  <b>1</b>등급
#  					</div>
#  </div>
#  <button class="otherButton" onclick="ToggleSellerItem('#li6842215', 'zzang8314', 'supply')" target="normal">
#  					판매자의 <b>다른상품</b>
#  </button>
#  <div class="others">
#  <ul></ul>
#  <a href="/main/item/itemList.php?sw=zzang8314&amp;sf=id" target="_blank">더보기 &gt;</a>
#  </div>
#  </li>, <li>도매꾹판매</li>, <li class="col3 " id="li7209600">
#  <a class="thumb" href="/s/7209600" target="_blank">
#  <img alt="상품이미지" onerror="this.src = 'http://211.43.195.137/image/item/img_notExist330.gif'" src="http://211.43.195.137//upload/item/2017/04/19/149257869917A7695C02003934369C5B/149257869917A7695C02003934369C5B_stt_330.png" title="상품이미지"/>
#  </a>
#  <div class="main">
#  <div class="paidIcon">
#  </div>
#  <a class="title" href="/s/7209600" target="_blank">[에스디몰]스키니롱트윌리스카프12종/스카프/머플러</a>
#  </div>
#  <div class="amtqty">
#  <div class="markCompanyBlock">
#  								사업자회원만
#  								구매가능
#  							</div>
#  <div class="infoDeli">선결제 <b>2,500</b>원~</div> </div>
#  <ul class="subinfo">
#  <li>도매꾹판매</li> </ul>
#  <div class="seller">
#  <div class="nick">
#  <img alt="우수판매자" height="13" src="http://211.43.195.137/image/item/list/ico_goodSeller.png" title="우수판매자" width="17"/><img alt="파워멤버" height="13" src="http://211.43.195.137/image/item/list/ico_powerMember.png" title="파워멤버" width="13"/>
#  <a href="?sw=escata&amp;sf=id">에스디몰</a>
#  </div>
#  <div class="id">(escata)</div> <div class="grade">
#  <b>1</b>등급
#  					</div>
#  </div>
#  <button class="otherButton" onclick="ToggleSellerItem('#li7209600', 'escata', 'supply')" target="normal">
#  					판매자의 <b>다른상품</b>
#  </button>
#  <div class="others">
#  <ul></ul>
#  <a href="/main/item/itemList.php?sw=escata&amp;sf=id" target="_blank">더보기 &gt;</a>
#  </div>
#  </li>, <li>도매꾹판매</li>, <li class="col0 " id="li7448742">
#  <a class="thumb" href="/s/7448742" target="_blank">
#  <img alt="상품이미지" onerror="this.src = 'http://211.43.195.137/image/item/img_notExist330.gif'" src="http://211.43.195.137//upload/item/2017/09/14/1505352688B063D6C68FD90958D01898/1505352688B063D6C68FD90958D01898_stt_330.png" title="상품이미지"/>
#  </a>
#  <div class="main">
#  <div class="paidIcon">
#  </div>
#  <a class="title" href="/s/7448742" target="_blank">[에스디몰]베이직트윌리12종/트윌리스카프/쁘띠머플러</a>
#  </div>
#  <div class="amtqty">
#  <div class="markCompanyBlock">
#  								사업자회원만
#  								구매가능
#  							</div>
#  <div class="infoDeli">선결제 <b>2,500</b>원~</div> </div>
#  <ul class="subinfo">
#  <li>도매꾹판매</li> </ul>
#  <div class="seller">
#  <div class="nick">
#  <img alt="우수판매자" height="13" src="http://211.43.195.137/image/item/list/ico_goodSeller.png" title="우수판매자" width="17"/><img alt="파워멤버" height="13" src="http://211.43.195.137/image/item/list/ico_powerMember.png" title="파워멤버" width="13"/>
#  <a href="?sw=escata&amp;sf=id">에스디몰</a>
#  </div>
#  <div class="id">(escata)</div> <div class="grade">
#  <b>1</b>등급
#  					</div>
#  </div>
#  <button class="otherButton" onclick="ToggleSellerItem('#li7448742', 'escata', 'supply')" target="normal">
#  					판매자의 <b>다른상품</b>
#  </button>
#  <div class="others">
#  <ul></ul>
#  <a href="/main/item/itemList.php?sw=escata&amp;sf=id" target="_blank">더보기 &gt;</a>
#  </div>
#  </li>, <li>도매꾹판매</li>, <li class="col1 " id="li7684455">
#  <a class="thumb" href="/s/7684455" target="_blank">
#  <img alt="상품이미지" onerror="this.src = 'http://211.43.195.137/image/item/img_notExist330.gif'" src="http://211.43.195.137//upload/item/2018/01/25/151687557078680E143AACDB66E07BC2/151687557078680E143AACDB66E07BC2_stt_330.png" title="상품이미지"/>
#  </a>
#  <div class="main">
#  <div class="paidIcon">
#  </div>
#  <a class="title" href="/s/7684455" target="_blank">[하이뷰] 1300/프리미엄 미끄럼방지 실리콘덧신11종</a>
#  </div>
#  <div class="amtqty">
#  <div class="markCompanyBlock">
#  								사업자회원만
#  								구매가능
#  							</div>
#  <div class="infoDeli">착불/선결제</div> </div>
#  <ul class="subinfo">
#  <li>도매꾹판매</li> </ul>
#  <div class="seller">
#  <div class="nick">
#  <img alt="우수판매자" height="13" src="http://211.43.195.137/image/item/list/ico_goodSeller.png" title="우수판매자" width="17"/><img alt="파워멤버" height="13" src="http://211.43.195.137/image/item/list/ico_powerMember.png" title="파워멤버" width="13"/>
#  <a href="?sw=trendview&amp;sf=id">trendview</a>
#  </div>
#  <div class="grade">
#  <b>1</b>등급
#  					</div>
#  <div class="fastdeli">빠른배송</div>
#  </div>
#  <button class="otherButton" onclick="ToggleSellerItem('#li7684455', 'trendview', 'supply')" target="normal">
#  					판매자의 <b>다른상품</b>
#  </button>
#  <div class="others">
#  <ul></ul>
#  <a href="/main/item/itemList.php?sw=trendview&amp;sf=id" target="_blank">더보기 &gt;</a>
#  </div>
#  </li>, <li>도매꾹판매</li>, <li class="col2 galleryMore" id="li7762430">
#  <a class="thumb" href="/s/7762430" target="_blank">
#  <img alt="상품이미지" onerror="this.src = 'http://211.43.195.137/image/item/img_notExist330.gif'" src="http://211.43.195.137//upload/item/2018/03/19/1521447290DFB135F086D59ADADF67A7/1521447290DFB135F086D59ADADF67A7_stt_330.png" title="상품이미지"/>
#  </a>
#  <div class="main">
#  <div class="paidIcon">
#  </div>
#  <a class="title" href="/s/7762430" target="_blank">[두리캡]아크릴대두볼캡/대두모자/착시모자/큰모자</a>
#  </div>
#  <div class="amtqty">
#  <div class="markCompanyBlock">
#  								사업자회원만
#  								구매가능
#  							</div>
#  <div class="infoDeli">선결제</div> </div>
#  <ul class="subinfo">
#  <li>도매꾹판매</li> </ul>
#  <div class="seller">
#  <div class="nick">
#  <img alt="우수판매자" height="13" src="http://211.43.195.137/image/item/list/ico_goodSeller.png" title="우수판매자" width="17"/>
#  <a href="?sw=csy5891&amp;sf=id">dooricap</a>
#  </div>
#  <div class="id">(csy5891)</div> <div class="grade">
#  <b>1</b>등급
#  					</div>
#  <div class="fastdeli">빠른배송</div>
#  </div>
#  <button class="otherButton" onclick="ToggleSellerItem('#li7762430', 'csy5891', 'supply')" target="normal">
#  					판매자의 <b>다른상품</b>
#  </button>
#  <div class="others">
#  <ul></ul>
#  <a href="/main/item/itemList.php?sw=csy5891&amp;sf=id" target="_blank">더보기 &gt;</a>
#  </div>
#  </li>, <li>도매꾹판매</li>, <li class="col3 galleryMore" id="li6892412">
#  <a class="thumb" href="/s/6892412" target="_blank">
#  <img alt="상품이미지" onerror="this.src = 'http://211.43.195.137/image/item/img_notExist330.gif'" src="http://211.43.195.137//upload/item/2016/07/28/1469682181DABDCEF3BE438DBE06788A/1469682181DABDCEF3BE438DBE06788A_stt_330.png" title="상품이미지"/>
#  </a>
#  <div class="main">
#  <div class="paidIcon">
#  </div>
#  <a class="title" href="/s/6892412" target="_blank">[에스디몰]데일리소프트페이크삭스/페이크삭스/덧신/</a>
#  </div>
#  <div class="amtqty">
#  <div class="markCompanyBlock">
#  								사업자회원만
#  								구매가능
#  							</div>
#  <div class="infoDeli">선결제 <b>2,500</b>원</div> </div>
#  <ul class="subinfo">
#  <li>도매꾹판매</li> </ul>
#  <div class="seller">
#  <div class="nick">
#  <img alt="우수판매자" height="13" src="http://211.43.195.137/image/item/list/ico_goodSeller.png" title="우수판매자" width="17"/><img alt="파워멤버" height="13" src="http://211.43.195.137/image/item/list/ico_powerMember.png" title="파워멤버" width="13"/>
#  <a href="?sw=bestmd3&amp;sf=id">부부파이</a>
#  </div>
#  <div class="id">(bestmd3)</div> <div class="grade">
#  <b>1</b>등급
#  					</div>
#  </div>
#  <button class="otherButton" onclick="ToggleSellerItem('#li6892412', 'bestmd3', 'supply')" target="normal">
#  					판매자의 <b>다른상품</b>
#  </button>
#  <div class="others">
#  <ul></ul>
#  <a href="/main/item/itemList.php?sw=bestmd3&amp;sf=id" target="_blank">더보기 &gt;</a>
#  </div>
#  </li>, <li>도매꾹판매</li>]

# %%
def domaemae_top100():
    df = pd.DataFrame(columns=["from", "catID" ,"rank","item_name", "price", "link"])
    for ID1 in range(0, 6):
        for ID2 in range(0, 5):
            response = requests.get(domaemae_cat_id_maker(ID1 + 1, ID2 + 1)) # html code로 가져옴
            response.encoding = 'euc-kr'
            html = response.content
            dom = BeautifulSoup(html, "html.parser") # 파싱
            lists = dom.select(".lItemList li") #여러개의 데이터 (리스트)
            for rnk, lst in enumerate(lists):
                df.loc[len(df)] = { 
                    "from":"도매매",
                    "catID":list(filter(lambda x: x!="", [cat if i == ID1 else "" for i, cat in enumerate (['패션잡화', '패션의류', '출산/육아', '가구/인테리어', '스포츠/레저', '디지털/가전',])]))[0], 
                    "rank":rnk + 1,
                    "item_name":lst.select_one(".main a:nth-of-type(1)").text,
                    "price":lst.select_one(".amtqty .infoDeli b").text,
                    "link":"http://domeme.domeggook.com" + lst.select_one(".main a").attrs['href']
                }
    return df

# %%
# %%time
domaemae_df = domaemae_top100()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <timed exec> in <module>()
#
# <ipython-input-58-38da56144508> in domaemae_top100()
#      13                     "catID":list(filter(lambda x: x!="", [cat if i == ID1 else "" for i, cat in enumerate (['패션잡화', '패션의류', '출산/육아', '가구/인테리어', '스포츠/레저', '디지털/가전',])]))[0],
#      14                     "rank":rnk + 1,
# ---> 15                     "item_name":lst.select_one(".main a:nth-of-type(1)").text,
#      16                     "price":lst.select_one(".amtqty .infoDeli b").text,
#      17                     "link":"http://domeme.domeggook.com" + lst.select_one(".main a").attrs['href']
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
domaemae_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-60-b2308c481a0c> in <module>()
# ----> 1 domaemae_df
#
# NameError: name 'domaemae_df' is not defined

# %% [markdown]
# # 11번가 100

# %%
def eleventhst_cat_id_maker(catID):
    url = "http://www.11st.co.kr/html/bestSellerMain" + str(catID) + ".html" 
    return url

# %%
def eleventhst_top100():
    df = pd.DataFrame(columns=["from", "catID" ,"rank","item_name", "price", "link", "date"])
    for ID in range(0, 9):
        response = requests.get(eleventhst_cat_id_maker(ID + 2)) # html code로 가져옴
        dom = BeautifulSoup(response.content, "html.parser") # 파싱
        lists = dom.select(".thumbnail_list ul li") #여러개의 데이터 (리스트)
        for rnk, lst in enumerate(lists):
            df.loc[len(df)] = {
                "from":"11번가",
                "catID":list(filter(lambda x: x!="", [cat if i == ID else "" for i, cat in enumerate (['패션의류', '패션잡화', '화장품/미용', '식품', '출산/육아', '가구/인테리어', '생활/건강', '스포츠/레저', '디지털/가전',])]))[0], 
                "rank":rnk + 1,
                "item_name":lst.select_one(".pup_info .pup_title a").text,
                "price":lst.select_one(".pup_info .pub_priceW .pub_salep").text.replace('~','').replace('원',''),
                "link":lst.select_one(".product_conts .pub_photo a").attrs['href'],
                "date":datetime.datetime.fromtimestamp(ts).strftime('%Y-%m-%d')
            }
    return df

# %%
# %%time
eleventhst_df = eleventhst_top100()
# Out:
# Wall time: 11.6 s

# %%
eleventhst_df
# Out:
#      from   catID rank                                        item_name  \
# 0    11번가    패션의류    1                    [30%할인+사은품]엠블러 반팔티/티셔츠/에코백/모자
# 1    11번가    패션의류    2                    30%쿠폰 특허받은 편안함 컴포트랩 코코브라렛/시스루
# 2    11번가    패션의류    3                     30%쿠폰!가정의달 TRY본사 온가족속옷 만원행사!
# 3    11번가    패션의류    4                  8900원으로 봄여름 전부 담기! 롱원피스/쉬폰/맨투맨/
# 4    11번가    패션의류    5                [럭키567] 15%+15%중복쿠폰!! 신상80종 파격할인!
# 5    11번가    패션의류    6                    [패션24시 30%쿠폰]체리코코 러블리 데이트룩 특가
# 6    11번가    패션의류    7                      [패션24시30%쿠폰][에이엘]예쁨주의!러블리코디
# 7    11번가    패션의류    8                   [노르웨이숲]30%쿠폰 봄여름 빅사이즈 신상 할인혜택!
# 8    11번가    패션의류    9                    루미씨 패션24시30%할인 마법팬츠! 청바지/빅사이즈
# 9    11번가    패션의류   10               4/20까지 11%+15%중복쿠폰! 모니카앤아리 신상80+균일
# 10   11번가    패션의류   11                  [앙투] 봄신상 원피스44~110빅사이즈 루즈핏 롱플라워
# 11   11번가    패션의류   12                 [시크헤라]봄신상 TOP100 ! 블라우스/린넨자켓/원피스
# 12   11번가    패션의류   13                   전부1900원 가정의달!국민속옷 TRY본사 트렁크大방출
# 13   11번가    패션의류   14                   [패션24시30%쿠폰][업타운홀릭]남들보다우월한 코디룩
# 14   11번가    패션의류   15                  15%쿠폰! 투투 ~3XL 슬랙스/청바지/부츠컷/빅사이즈
# 15   11번가    패션의류   16                     더다다 5900원부터! 봄신상 루즈핏 티셔츠/원피스
# 16   11번가    패션의류   17                  [패션24시30%쿠폰][코코리]루즈핏/맨투맨/롱원피스/티
# 17   11번가    패션의류   18                      30%쿠폰L.LAMO 반팔티셔츠/빅사이즈/남녀공용
# 18   11번가    패션의류   19                     [패션24시 30%쿠폰]애프리콧 봄신상 가디건/니트
# 19   11번가    패션의류   20                   [패션24시30%쿠폰][요즘에]청바지/슬랙스/반바지출시
# 20   11번가    패션의류   21                     30%쿠폰꿀잠!속옷미인 봄여름커플잠옷/피치기모홈웨어
# 21   11번가    패션의류   22                    듀클라이 프리미엄 반팔티 M~3XL 빅사이즈 남여공용
# 22   11번가    패션의류   23                       [에스티아]빅사이즈no상관/원피스/티셔츠/롱후드
# 23   11번가    패션의류   24                   [난닝구]11%+15%쿠폰!루즈핏/티셔츠/원피스/스커트
# 24   11번가    패션의류   25                         마크막스 선착순특가 린넨자켓/꽃블라우스/셔츠
# 25   11번가    패션의류   26                   [에이와비]15%쿠폰 봄여름 신상 티셔츠/청바지/원피스
# 26   11번가    패션의류   27                     [르젠]신상특가 남성 슬랙스/면바지/밴딩바지/청바지
# 27   11번가    패션의류   28                              올시즌 데님코디제안! 봄봄한 봄신상
# 28   11번가    패션의류   29                  [30%쿠폰+단독특가!]XL까지/하객룩/오피스/정장원피스
# 29   11번가    패션의류   30                 [그랜피니] 2018 NEW 신상 반팔/긴팔/반바지/오버핏
# ..    ...     ...  ...                                              ...
# 870  11번가  디지털/가전   71             공식파트너 삼성 138cm LED TV UN55M5550AFXKR
# 871  11번가  디지털/가전   72                 인증점M 삼성 H9000 RH81M8000SA 전국무료배송
# 872  11번가  디지털/가전   73                            캐쉬백3만원 다이슨 공기청정기 TP04
# 873  11번가  디지털/가전   74               [카드10%적용가861,300원]갤럭시S9/S9+자급제폰언락폰
# 874  11번가  디지털/가전   75              제닉스 TITAN MARK VII (청축) 기계식/게이밍/키보드
# 875  11번가  디지털/가전   76                   Apple Pencil 애플 펜슬 [MK0C2KH/A]
# 876  11번가  디지털/가전   77           [삼성전자] AX90M7580WPD 삼성 블루스카이 공기청정기 /SH
# 877  11번가  디지털/가전   78               특가 46만/삼성 노트북5 NT500R3W-LD2A 삼성마우스
# 878  11번가  디지털/가전   79                  LG 휘센 SQ062BS1W 벽걸이형 1등급 기본설치포함
# 879  11번가  디지털/가전   80                     인증점 삼성 벽걸이 무풍에어컨 AR07M5170HA
# 880  11번가  디지털/가전   81                (정품)삼성 아이콘X 2018 블루투스이어폰(SM-R140)
# 881  11번가  디지털/가전   82                        [구글코리아]구글크롬캐스트2/14시주문당일발송
# 882  11번가  디지털/가전   83                인증점 삼성 공기청정기 큐브 AX47N9880WFD 무료배송
# 883  11번가  디지털/가전   84         [LG전자] LG 통돌이 세탁기 블랙라벨플러스 T15SS 15kg  실버
# 884  11번가  디지털/가전   85                        삼성인증점H)드럼세탁기 WF14F5K3AVW1
# 885  11번가  디지털/가전   86         35만원혜택! 20만원할인+MSoffice증정 NT900X5T-X716A
# 886  11번가  디지털/가전   87                    엘지전자 OLED55C6K 안전직배송 폐기수거 에스몰
# 887  11번가  디지털/가전   88                           [리퍼 특가] 발뮤다 에어엔진 공기청정기
# 888  11번가  디지털/가전   89    [파격가 71만] MSI GL62M 7RDX-i5 (1492) i5/1050/8G
# 889  11번가  디지털/가전   90                  기기전액포함가! JOON 스페셜에디션 SKT 키즈 완납폰
# 890  11번가  디지털/가전   91                인증점M 삼성 무풍에어컨 AF16M7574WVR 기본설치포함
# 891  11번가  디지털/가전   92           최종 38만 HP i3 올인원 노트북 15-bs566TU/SSD128
# 892  11번가  디지털/가전   93  [특가83만] MSI GL62M 7RDX-i7 (1491) i7/1050/8G/IPS
# 893  11번가  디지털/가전   94                 LG 퓨리케어 공기청정기 AS112VDS 38㎡ 청정 탈취
# 894  11번가  디지털/가전   95          상품평10만(공식파트너)삼성189cm UHD TV UN75MU6350F
# 895  11번가  디지털/가전   96                 [LG스페셜에디션]톤플러스HBS-1100 블루투스이어폰 B
# 896  11번가  디지털/가전   97          i5탑재/Free-DOS 삼성노트북5의 자존심 NT500R3W-LD5A
# 897  11번가  디지털/가전   98                      LG전자 S839SS32 양문형 냉장고 (주)대명
# 898  11번가  디지털/가전   99                      [카드추가할인] 휴스톰 물걸레청소기 HS-9000
# 899  11번가  디지털/가전  100                    샌디스크 SD카드/마이크로SD 메모리 모음! 모든용량
#
#          price                                               link        date
# 0        7,900  http://www.11st.co.kr/product/SellerProductDet...  2018-04-21
# 1       10,000  http://www.11st.co.kr/product/SellerProductDet...  2018-04-21
# 2       10,000  http://www.11st.co.kr/product/SellerProductDet...  2018-04-21
# 3        8,900  http://www.11st.co.kr/product/SellerProductDet...  2018-04-21
# 4       13,900  http://www.11st.co.kr/product/SellerProductDet...  2018-04-21
# 5       22,400  http://www.11st.co.kr/product/SellerProductDet...  2018-04-21
# 6        5,900  http://www.11st.co.kr/product/SellerProductDet...  2018-04-21
# 7       12,900  http://www.11st.co.kr/product/SellerProductDet...  2018-04-21
# 8       15,800  http://www.11st.co.kr/product/SellerProductDet...  2018-04-21
# 9        8,900  http://www.11st.co.kr/product/SellerProductDet...  2018-04-21
# 10      12,800  http://www.11st.co.kr/product/SellerProductDet...  2018-04-21
# 11      16,900  http://www.11st.co.kr/product/SellerProductDet...  2018-04-21
# 12       1,900  http://www.11st.co.kr/product/SellerProductDet...  2018-04-21
# 13      19,800  http://www.11st.co.kr/product/SellerProductDet...  2018-04-21
# 14       6,900  http://www.11st.co.kr/product/SellerProductDet...  2018-04-21
# 15       5,900  http://www.11st.co.kr/product/SellerProductDet...  2018-04-21
# 16       6,900  http://www.11st.co.kr/product/SellerProductDet...  2018-04-21
# 17       9,800  http://www.11st.co.kr/product/SellerProductDet...  2018-04-21
# 18       8,900  http://www.11st.co.kr/product/SellerProductDet...  2018-04-21
# 19       9,900  http://www.11st.co.kr/product/SellerProductDet...  2018-04-21
# 20       5,800  http://www.11st.co.kr/product/SellerProductDet...  2018-04-21
# 21       7,900  http://www.11st.co.kr/product/SellerProductDet...  2018-04-21
# 22      12,900  http://www.11st.co.kr/product/SellerProductDet...  2018-04-21
# 23      15,000  http://www.11st.co.kr/product/SellerProductDet...  2018-04-21
# 24      12,900  http://www.11st.co.kr/product/SellerProductDet...  2018-04-21
# 25      14,900  http://www.11st.co.kr/product/SellerProductDet...  2018-04-21
# 26      14,800  http://www.11st.co.kr/product/SellerProductDet...  2018-04-21
# 27       9,800  http://www.11st.co.kr/product/SellerProductDet...  2018-04-21
# 28      19,700  http://www.11st.co.kr/product/SellerProductDet...  2018-04-21
# 29       9,900  http://www.11st.co.kr/product/SellerProductDet...  2018-04-21
# ..         ...                                                ...         ...
# 870    769,000  http://www.11st.co.kr/product/SellerProductDet...  2018-04-21
# 871  1,379,000  http://www.11st.co.kr/product/SellerProductDet...  2018-04-21
# 872    787,000  http://www.11st.co.kr/product/SellerProductDet...  2018-04-21
# 873    957,000  http://www.11st.co.kr/product/SellerProductDet...  2018-04-21
# 874     79,900  http://www.11st.co.kr/product/SellerProductDet...  2018-04-21
# 875    119,000  http://www.11st.co.kr/product/SellerProductDet...  2018-04-21
# 876    659,500  http://www.11st.co.kr/product/SellerProductDet...  2018-04-21
# 877    499,000  http://www.11st.co.kr/product/SellerProductDet...  2018-04-21
# 878    693,900  http://www.11st.co.kr/product/SellerProductDet...  2018-04-21
# 879    829,000  http://www.11st.co.kr/product/SellerProductDet...  2018-04-21
# 880    189,410  http://www.11st.co.kr/product/SellerProductDet...  2018-04-21
# 881     50,960  http://www.11st.co.kr/product/SellerProductDet...  2018-04-21
# 882    661,900  http://www.11st.co.kr/product/SellerProductDet...  2018-04-21
# 883    599,000  http://www.11st.co.kr/product/SellerProductDet...  2018-04-21
# 884    599,000  http://www.11st.co.kr/product/SellerProductDet...  2018-04-21
# 885  1,999,000  http://www.11st.co.kr/product/SellerProductDet...  2018-04-21
# 886  3,244,700  http://www.11st.co.kr/product/SellerProductDet...  2018-04-21
# 887    439,000  http://www.11st.co.kr/product/SellerProductDet...  2018-04-21
# 888    766,000  http://www.11st.co.kr/product/SellerProductDet...  2018-04-21
# 889     30,210  http://www.11st.co.kr/product/SellerProductDet...  2018-04-21
# 890  1,979,000  http://www.11st.co.kr/product/SellerProductDet...  2018-04-21
# 891    419,000  http://www.11st.co.kr/product/SellerProductDet...  2018-04-21
# 892    896,000  http://www.11st.co.kr/product/SellerProductDet...  2018-04-21
# 893    271,800  http://www.11st.co.kr/product/SellerProductDet...  2018-04-21
# 894  2,659,000  http://www.11st.co.kr/product/SellerProductDet...  2018-04-21
# 895    139,000  http://www.11st.co.kr/product/SellerProductDet...  2018-04-21
# 896    699,000  http://www.11st.co.kr/product/SellerProductDet...  2018-04-21
# 897  1,278,000  http://www.11st.co.kr/product/SellerProductDet...  2018-04-21
# 898    169,000  http://www.11st.co.kr/product/SellerProductDet...  2018-04-21
# 899      6,600  http://www.11st.co.kr/product/SellerProductDet...  2018-04-21
#
# [900 rows x 7 columns]

# %% [markdown]
# # G마켓 200
# - request로 불가능 (태그안에 데이터를 가져오지 못함)

# %%
# def gmarket_cat_id_maker(catID):
#     url = "http://corners.gmarket.co.kr/Bestsellers?viewType=G&groupCode=G0" + str(catID)
#     return url

# %%
# response = requests.get(gmarket_cat_id_maker(1)) # html code로 가져옴
# response.encoding = 'euc-kr'
# html = response.text
# dom = BeautifulSoup(html, "html.parser") # 파싱
# lists = dom.select(".best-list li") #여러개의 데이터 (리스트)

# %%
# def gmarket_top200():
#     df = pd.DataFrame(columns=["from", "catID" ,"rank","item_name", "price", "link"])
#     for ID in range(0, 9):
#         response = requests.get(gmarket_cat_id_maker(ID + 1)) # html code로 가져옴
#         dom = BeautifulSoup(response.content, "html.parser") # 파싱
#         lists = dom.select(".best-list li") #여러개의 데이터 (리스트)
#         for rnk, lst in enumerate(lists):
#             df.loc[len(df)] = {
#                 "from":"Gmarket",
#                 "catID":list(filter(lambda x: x!="", [cat if i == ID else "" for i, cat in enumerate (['패션의류', '패션잡화', '화장품/미용', '출산/육아', '스포츠/레저', '디지털/가전', '식품', '생활/건강', '가구/인테리어',])]))[0], 
#                 "rank":rnk + 1,
#                 "item_name":lst.select_one(".thumb a:nth-of-type(2)").text,
#                 "price":lst.select_one(".item_price div:nth-of-type(2) span").text,
#                 "link":lst.select_one(".thumb a").attrs['href']
#             }
#     return df

# %%
# %%time
# gmarket_df = gmarket_top200()

# %% [markdown]
# # DB 저장

# %%
client = pymongo.MongoClient("mongodb://localhost:27017/")
client
# Out:
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True)

# %%
db = client.crawl_data

# %%
data = client.crawl_data.data

# %%
naver = naver_df.to_dict('records')

# %%
domaeggook = domaeggook_df.to_dict('records')

# %%
eleventhst = eleventhst_df.to_dict('records')

# %%
data.insert_many(naver)
data.insert_many(domaeggook)
data.insert_many(eleventhst)

# %%
MONGO_QUERY = {}

# %%
data.find(MONGO_QUERY).count()
# Out:
# 12000
